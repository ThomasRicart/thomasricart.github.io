# %% [markdown]
# <div style="background-color:#1e1e1e;border-radius:12px;overflow:hidden;font-family:'Consolas','Monaco',monospace;box-shadow:0 10px 30px rgba(0,0,0,0.5);border:1px solid #333;">
#     <div style="background-color:#333;padding:12px;display:flex;align-items:center;gap:8px;">
#         <div style="width:12px;height:12px;background:#ff5f56;border-radius:50%;"></div>
#         <div style="width:12px;height:12px;background:#ffbd2e;border-radius:50%;"></div>
#         <div style="width:12px;height:12px;background:#27c93f;border-radius:50%;"></div>
#         <span style="color:#aaa;font-size:13px;margin-left:15px;font-weight:bold;letter-spacing:0.5px;">AP05-ACT2-listes.ipynb</span>
#     </div>
#     <div style="padding:30px;color:#d4d4d4;line-height:1.6;">
#         <h1 style="color:#569cd6;margin-top:0;border-bottom:1px solid #444;padding-bottom:10px;">AP05 : Les Listes / Tuples - ACTIVITE 02</h1>
#         <p style="color:#ce9178;margin:15px 0 5px 0;font-size:1.2em;font-weight:bold;"># Thème : Langage de Programmation</p>
#         <p style="color:#9cdcfe;margin:0;font-size:1.1em;font-weight:bold;"># Niveau : 1ère NSI</p>
#         <div style="margin-top:25px;background-color:#252526;padding:15px;border-radius:8px;border-left:4px solid #4ec9b0;">
#
# </div>

# %% [markdown]
# <h1 class="alert alert-info"><center>Activité : parcours de listes</center></h1>

# %% [markdown]
# <p>Le but de cette activité est de manipuler les parcours de listes par indices et par éléments.</p>

# %% [markdown]
# <h2 class="alert alert-info">Exercice 1 : affichage d'éléments</h2>

# %% [markdown]
# On a saisi dans une liste `liste_livres` l'ensemble des livres d'une bibliothèque.
#
# 1. Compléter le code suivant pour pouvoir afficher tous les livres de la bibliothèque :

# %%
bibliothèque = ['Barjavel','Endymion','Hypérion','La planète des singes']

# %%
def affichage_livres(liste_livres):
    '''Affiche les éléments d'une liste de livres.'''
    for i in range(...):
        print(liste_livres[...])

# %%
# Tester votre fonction avec la bibliothèque

# %% [markdown]
# 2. Modifier le code de la question 1 pour effectuer un parcours par éléments de la liste `liste_livres`.

# %%
def affichage_livres(liste_livres):
    '''Affiche les éléments d'une liste de livres.'''
    for ... :
        print(...)

# %% [markdown]
# <h2 class="alert alert-info">Exercice 2 : comptage d'éléments (partie 1)</h2>

# %% [markdown]
# Un brin d'ADN est constitué des nucléotides A, C, T et G. Un tel brin est codé sous forme d'une liste de caractères, par exemple `['A', 'C', 'C', 'T', 'A', 'G']`.
#
# 1. Compléter la fonction suivante qui va compter le nombre de nucléotides `N` présents dans un brin d'ADN donné :

# %%
def compte_nucléotide_A(brin_ADN, N):
    '''Compte le nombre de nucléotides N dans un brin d'ADN donné.'''

# %% [markdown]
# Que renvoie l'instruction `compte_nucléotide_A('ACCTAG')` ? Interpréter ce résultat concrètement.

# %% [markdown]
# <p style="font-style:italic; color:gray;">Ecrire la réponse ici</p>

# %% [markdown]
# 2. Modifier le code de la fonction précédente pour qu'elle renvoie le nombre de chaque nucléotide présent dans le brin d'ADN.
#
# On utilisera quatre variables et on renverra un tuple consitué des valeurs dans l'ordre suivant : nombre de nucléotides A, nombre de nucléotides C, nombre de nucléotides T et nombre de nucléotides G.

# %%
def compte_tous_les_nucléotides(brin_ADN):
    '''Compte le nombre de chaque nucléotide présent dans un brin d'ADN donné.'''
    # code à compléter

# %% [markdown]
# La cellule suivante permet de tester votre fonction. Elle doit renvoyer `True` lors de son exécution.

# %%
compte_tous_les_nucléotides(['A', 'C', 'C', 'T', 'A', 'G']) == (2, 2, 1, 1)

# %% [markdown]
# <h2 class="alert alert-info">Exercice 3 : comptage d'éléments (partie 2)</h2>

# %% [markdown]
# 1. Une liste `liste_valeurs` contient des valeurs entières aléatoires comprises entre $0$ et $5$. Pour compter le nombre de fois où chacune des valeurs $0$, $1$, $2$, $3$, $4$ et $5$ apparaît dans cette liste, on procède de la façon suivante :
#  - on initialise une liste `effectifs_valeurs` à `[0,0,0,0,0,0]`;
#  - on parcourt la liste `liste_valeurs` ;
#  - pour chaque valeur `valeur` rencontrée dans la liste `liste_valeurs`, on augmente de $1$ la valeur située à l'indice `valeur`de la liste `effectifs_valeurs` ;
#  - une fois la liste `liste_valeurs` entièrement parcourue, l'élément d'indice `0`de `effectifs_valeurs` contient le nombre de fois où `0` apparaît dans `liste_valeurs`, l'élément d'indice `1`de `effectifs_valeurs` contient le nombre de fois où `1` apparaît dans `liste_valeurs`, l'élément d'indice `2`de `effectifs_valeurs` contient le nombre de fois où `2` apparaît dans `liste_valeurs`, etc...
#
# Par exemple, si `liste_valeurs = [0,1,2,5,4,4,3,2,4,5,0,1,0,0,2,3,4]`, alord `effectifs_valeurs` contient la liste `[4,2,3,2,4,2]`.
#
# Compléter la fonction ci-dessous afin qu'elle renvoie la liste `effectifs_valeurs` à partir de la liste `liste_valeurs`.

# %%
def calcul_effectifs(liste_valeurs):
    '''Calcule les effectifs de chaque valeur présente dans une liste donnée.'''
    effectifs_valeurs = ...
    for val in ... :
        effectifs_valeurs[...] = ...
    return effectifs_valeurs

# %% [markdown]
# La cellule suivante permet de tester votre fonction. Elle doit renvoyer `True` lors de son exécution.

# %%
calcul_effectifs([0,1,2,5,4,4,3,2,4,5,0,1,0,0,2,3,4]) == [4,2,3,2,4,2]

# %% [markdown]
# 2. Modifier la fonction précédente en une fonction `calcul_effectifs2` pour qu'elle fonctionne avec une liste `liste_valeurs` contenant des valeurs entières aléatoires comprises entre deux entiers `n` et `m` avec `n < m`.
#
# Ainsi, l'instruction `calcul_effectifs2([0,1,2,5,4,4,3,2,4,5,0,1,0,0,2,3,4],0,5)` devra renvoyer `[4,2,3,2,4,2]`.

# %%
def calcul_effectifs2(liste_valeurs,n,m):
    ''''Calcule les effectifs de chaque valeur présente dans une liste donnée, en supposant que les valeurs sont des entiers compris entre n et m.'''
    # code à compléter

# %% [markdown]
# Les trois cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
calcul_effectifs2([0,1,2,5,4,4,3,2,4,5,0,1,0,0,2,3,4],0,5) == [4,2,3,2,4,2]

# %%
calcul_effectifs2([2,4,5,6,8,2,2,5,4,7,2,5,6,8,9,5,8,6,2,4,6,9,9],2,9) == [5, 0, 3, 4, 4, 1, 3, 3]

# %%
calcul_effectifs2([-1,0,2,-1,4,5,-1,-2,5,6,3,-1,0,4,2,5,3,5,4],-2,6) == [1, 4, 2, 0, 2, 2, 3, 4, 1]

# %% [markdown]
# <h2 class="alert alert-info">Exercice 4 : seuillage (partie 1)</h2>

# %% [markdown]
# La fonction `seuil_liste` ci-dessous prend en paramètre une liste numérique non vide `L` et une valeur numérique `val`, et renvoie la liste `L` dans laquelle tous les éléments de `L` supérieurs ou égaux à `val` ont été remplacés par `0`.
#
# Compléter cette fonction.

# %%
def seuil_liste(L,val):
    '''Remplace les éléments d'une liste par 0 s'ils sont supérieurs ou égaux à une valeur donnée.'''
    
    for i in range(...):
        if ... >= ... :
            ... = 0
    return L

# %% [markdown]
# Les trois cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
seuil_liste([1,5,3,2,4,5,7,3,5,6,7,1,2],5) == [1,0,3,2,4,0,0,3,0,0,0,1,2]

# %%
seuil_liste([8,4,3,2,2.1,4,5,6],1) == [0,0,0,0,0,0,0,0]

# %%
seuil_liste([4,5,0.8,4,3,2,4],9) == [4,5,0.8,4,3,2,4]

# %% [markdown]
# <h2 class="alert alert-info">Exercice 5 : seuillage (partie 2)</h2>

# %% [markdown]
# Une image numérique en niveau de gris peut être vue comme une liste dont les valeurs sont des nombres entiers compris entre $0$ et $255$.
#
# Pour convertir une telle image en noir et blanc, on parcourt la liste précédente et on effectue les modifications suivantes :
#  - si la valeur que l'on regarde est strictement inférieure à $127$, on la remplace par $0$ ;
#  - si la valeur que l'on regarde est supérieure ou égale à $127$, on la remplace par $255$.
#
# En s'aidant de la fonction écrite à l'exercice 6, écrire une fonction `noir_et_blanc` prenant en paramètre une liste `img` correspondant à une image numérique en niveau de gris, et renvoyant la liste correspondant à l'image en noir et blanc obtenue par la méthode décrite ci-dessus.
#
# _On ne fera pas de tests d'assertion._

# %%
def noir_et_blanc(img):
    '''Transforme une image en noir et blanc.'''
    # code à compléter

# %% [markdown]
# Les trois cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
noir_et_blanc([12,58,2,6,126,48,68]) == [0,0,0,0,0,0,0]

# %%
noir_et_blanc([127,250,185,146,158,200,147,129]) == [255,255,255,255,255,255,255,255]

# %%
noir_et_blanc([124,53,127,189,15,147,152,3,123]) == [0,0,255,255,0,255,255,0,0]

# %% [markdown]
# <h2 class="alert alert-info">Exercice 6 : somme et moyenne</h2>

# %% [markdown]
# 1. La fonction `somme` ci-dessous prend en paramètre une liste numérique non vide `L` et renvoie la somme de ses éléments.
#
# Compléter cette fonction.

# %%
def somme(L):
    '''Calcule la somme des éléments d'une liste numérique donnée.'''
    somme_valeurs = ...
    for elem in L:
        somme_valeurs = ... + ...
    return somme_valeurs

# %% [markdown]
# Les trois cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
somme([5]) == 5

# %%
somme([1,2,3]) == 6

# %%
somme([2,17,5,-5,6,7]) == 32

# %% [markdown]
# 2. Réécrire ci-dessous la fonction `somme` précédente en effectuant un parcours de la liste `L` par indice.

# %%
def somme_bis(L):
    '''Calcule la somme des éléments d'une liste numérique donnée, en utilisant une boucle for avec un indice.'''
    # code à compléter

# %% [markdown]
# 3. En utilisant la fonction `somme`, écrire une fonction `moyenne` prenant en paramètre une liste numérique non vide `L` et renvoyant la moyenne de ses valeurs. _On ne fera pas de tests d'assertion._

# %%
def moyenne(L):
    '''Calcule la moyenne des éléments d'une liste numérique donnée.'''
    # code à compléter

# %% [markdown]
# Les trois cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
moyenne([5]) == 5.0

# %%
moyenne([1,2,3]) == 2.0

# %%
moyenne([2,17,5,-5,6,7]) == 5.333333333333333

# %% [markdown]
# <h2 class="alert alert-info">Exercice 8 : appartenance (partie 1)</h2>

# %% [markdown]
# La fonction `appartient` ci-dessous prend en paramètre une liste `L` et une valeur `val`, et renvoie `True` si `val` appartient à `L` et `False` sinon.
#
# Compléter cette fonction.

# %%
def appartient(L,val):
    '''Vérifie si une valeur donnée appartient à une liste donnée.'''
    for elem in L:
        if elem == ... :
            return ...
    return ...

# %% [markdown]
# Les six cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
appartient([],5) == False

# %%
appartient([6],6) == True

# %%
appartient([7],-1) == False

# %%
appartient([1,5,3,2,4],3) == True

# %%
appartient([1,3,4,5,6,2,1,2,3],8) == False

# %%
appartient([1,2,0,-5,4,2,3,'A'],'A') == True

# %% [markdown]
# <h2 class="alert alert-info">Exercice 9 : appartenance (partie 2)</h2>

# %% [markdown]
# 1. La fonction `recherche_indice_min` ci-dessous prend en paramètre une liste `L` et une valeur `val`, et renvoie l'indice de la première occurence de `val` si `val` appartient à `L`, et `-1` si `val` n'appartient pas à `L`.
#
# Compléter cette fonction.

# %%
def recherche_indice_min(L,val):
    '''Recherche l'indice de la première occurrence d'une valeur donnée dans une liste donnée.'''
    for i in range(...):
        if ... == val:
            return ...
    return -1

# %% [markdown]
# Les six cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
recherche_indice_min([],5) == -1

# %%
recherche_indice_min([6],6) == 0

# %%
recherche_indice_min([7],-1) == -1

# %%
recherche_indice_min([1,5,3,2,4],3) == 2

# %%
recherche_indice_min([1,3,4,5,6,2,1,2,3],8) == -1

# %%
recherche_indice_min([1,2,0,-5,4,2,3,'A'],2) == 1

# %% [markdown]
# 2. En s'aidant de la fonction précédente, écrire une fonction `recherche_indice_max` qui prend en paramètre une liste `L` et une valeur `val`, et renvoie l'indice de la dernière occurence de `val` si `val` appartient à `L`, et `-1` si `val` n'appartient pas à `L`.

# %%
def recherche_indice_max(L,val):
    '''Recherche l'indice de la dernière occurrence d'une valeur donnée dans une liste donnée.'''
    # code à compléter

# %% [markdown]
# Les six cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
recherche_indice_max([],5) == -1

# %%
recherche_indice_max([6],6) == 0

# %%
recherche_indice_max([7],-1) == -1

# %%
recherche_indice_max([1,5,3,2,4],3) == 2

# %%
recherche_indice_max([1,3,4,5,6,2,1,2,3],8) == -1

# %%
recherche_indice_max([1,2,0,-5,4,2,3,'A'],2) == 5

# %% [markdown]
# 3. En utilisant une liste par compréhension, écrire une fonction `recherche_indices` qui prend en paramètre une liste `L` et une valeur `val`, et renvoie une liste contenant tous les indices des occurences de `val` si `val` appartient à `L`, et une liste vide si `val` n'appartient pas à `L`.
#
# Avant d'effectuer la recherche, la fonction réalisera un test d'assertion pour vérifier que `L` est bien une liste.

# %%
def recherche_indices(L,val):
    '''Recherche les indices de toutes les occurrences d'une valeur donnée dans une liste donnée.'''
    # code à compléter

# %% [markdown]
# Les six cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
recherche_indices([],5) == []

# %%
recherche_indices([6],6) == [0]

# %%
recherche_indices([7],-1) == []

# %%
recherche_indices([1,5,3,2,4],3) == [2]

# %%
recherche_indices([1,3,4,5,6,2,1,2,3],8) == []

# %%
recherche_indices([1,2,0,-5,4,2,3,'A'],2) == [1,5]

# %% [markdown]
# <h2 class="alert alert-info">Exercice 10 : plus petit et plus grand élément d'une liste</h2>

# %% [markdown]
# 1. La fonction `minimum_liste` ci-dessous prend en paramètre une liste numérique non vide `L` et renvoie la plus petite valeur de cette liste, ainsi que l'indice de sa première occurence.
#
# Compléter cette fonction.

# %%
def minimum_liste(L):
    '''Calcule la valeur minimale d'une liste numérique donnée, ainsi que l'indice de la première occurrence de cette valeur minimale.'''
    val_min = L[0] # val_min stocke la valeur minimale
    indice_val_min = ... # indice_val_min stocke l'indice de la première occurence de la valeur minimale
    for i in range(...,...):
        if ... < ...
            val_min = ...
            indice_val_min = ...
    return val_min, indice_val_min

# %% [markdown]
# Les quatre cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
minimum_liste([5]) == (5,0)

# %%
minimum_liste([5,3,4,5,8,6,4,5,9,7]) == (3,1)

# %%
minimum_liste([9,4,3,5,6,8,4,6,1]) == (1,8)

# %%
minimum_liste([2,5,3,4,1,2,8,4,1,5,8,3]) == (1,4)

# %% [markdown]
# 2. En s'aidant de la fonction ci-dessus, écrire une fonction `maximum_liste` qui prend en paramètre une liste numérique non vide `L` et renvoie la plus grande valeur de cette liste, ainsi que l'indice de sa première occurence.

# %%
def maximum_liste(L):
    '''Calcule la valeur maximale d'une liste numérique donnée, ainsi que l'indice de la première occurrence de cette valeur maximale.'''
    # code à compléter

# %% [markdown]
# Les quatre cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
maximum_liste([5]) == (5,0)

# %%
maximum_liste([5,3,4,5,8,6,4,5,9,7]) == (9,8)

# %%
maximum_liste([9,4,3,5,6,8,4,6,1]) == (9,0)

# %%
maximum_liste([2,5,3,4,1,2,8,4,1,5,8,3]) == (8,6)

# %% [markdown]
# <h2 class="alert alert-warning"><center>Pour aller plus loin</center></h2>

# %% [markdown]
# <h2 class="alert alert-info">Exercice 1 : moyenne pondérée</h2>

# %% [markdown]
# La fonction `moyenne_pondérée` ci-dessous prend en paramètre deux listes numériques non vides de même longueur `valeurs` et `coefficients`, et renvoie la moyenne pondérées des éléments de `valeurs` par les éléments de `coefficients`.
#
# Compléter cette fonction.

# %%
def moyenne_pondérée(valeurs,coefficients):
    '''Calcule la moyenne pondérées des éléments de `valeurs` par les éléments de `coefficients`.'''
    somme_valeurs_ponderees = 0
    somme_coefficients = 0
    for i in range(...):
        somme_valeurs_ponderees = ...
        somme_coefficients = ...
    return somme_valeurs_ponderees/somme_coefficients

# %% [markdown]
# Les deux cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
moyenne_pondérée([5],[2]) == 5.0

# %%
moyenne_pondérée([1,2,3],[0.5,2,4]) == 2.5384615384615383

# %% [markdown]
# <h2 class="alert alert-info">Exercice 2 : palindrome</h2>

# %% [markdown]
# Une chaîne de caractères est appelée _palindrome_ si elle peut être lue dans les deux sens. Par exemple, `'radar'` est un palindrome, mais `'voiture'` ne l'est pas.
#
# Pour vérifier qu'une chaîne de caractères est un palindrome, on peut procéder de la façon suivante :
#  - on transtype la chaîne de caractères en une liste de telle sorte que chaque caractère de la chaîne soit un élément de la liste ;
#  - on parcourt simultanément la liste par indice depuis le début et la fin :
#   - tant que les deux caractères correspondent, on continue de parcourir la liste de cette manière ;
#   - si deux caractères ne correspondent pas, on s'arrête et on renvoie Faux ;
#   - si l'indice représentant le début devient supérieur ou égal à l'indice représentant la fin, on s'arrête et on renvoie Vrai.
#
# Compléter la fonction `est_palindrome` ci-dessous qui prend en paramètre une chaîne de caractères `chaine`, et renvoie `True` si la chaîne est un palindrome et `False` sinon.

# %%
def est_palindrome(chaine):
    ''''Vérifie si une chaîne de caractères donnée est un palindrome.'''
    listeChaine = ... # transtypage de chaine en une liste
    debut = ... # indice du début de liste_chaine
    fin = ... # indice de la fin de liste_chaine
    while ... < ... :
        if ... :
            return ...
        debut = ...
        fin = ...
    return ...

# %% [markdown]
# Les quatre cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
est_palindrome('radar') == True

# %%
est_palindrome('aabbaa') == True

# %%
est_palindrome('voiture') == False

# %%
est_palindrome('aaabbaa') == False

# %% [markdown]
# <h2 class="alert alert-info">Exercice 3 : suppression multiple</h2>

# %% [markdown]
# 1. La fonction `supprime_tout` ci-dessous prend en paramètre une liste `L` et une valeur `e`, et renvoie une liste contenant tous les éléments de `L` sauf les occurrences de `e`.
#
# Compléter cette fonction à l'aide d'une liste par compréhension.

# %%
def supprime_tout(L,e):
    '''Supprime toutes les occurrences d'une valeur donnée dans une liste donnée.'''


    return ...

# %% [markdown]
# Les cinq cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
supprime_tout([],5) == []

# %%
supprime_tout([1,5,3,4,6,8,4],9) == [1,5,3,4,6,8,4]

# %%
supprime_tout([2,5,1,3,2,2,4,5],2) == [5,1,3,4,5]

# %%
supprime_tout([1,1,1,1,1,1,1],1) == []

# %%
supprime_tout(list('ACCTAAGT'),'A') == ['C','C','T','G','T']

# %% [markdown]
# 2. La fonction `supprime_tout_et_renvoie` ci-dessous prend en paramètre une liste `L` et une liste `Li` de nombres entiers compris entre `0` et `len(L)-1`, et renvoie deux listes :
#  - la première contenant tous les éléments de `L` sauf les éléments dont les indices dans `L` sont donnés par les éléments de `Li` ;
#  - la seconde contenant tous les éléments de `L`dont les indices sont donnés par les éléments de `Li`.
#
# Compléter cette fonction à l'aide de deux listes par compréhension.

# %%
def supprime_tout_et_renvoie(L,Li):
    ''''Supprime toutes les occurrences des éléments d'une liste donnée dans une autre liste donnée, et renvoie la liste des éléments supprimés.'''
    

    
    return ... , ...

# %% [markdown]
# Les cinq cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
supprime_tout_et_renvoie([1,5,3,4,5],[]) == ([1,5,3,4,5], [])

# %%
supprime_tout_et_renvoie([4,5,2,3,4,-1,7],[5]) == ([4,5,2,3,4,7],[-1])

# %%
supprime_tout_et_renvoie([2,5,1,3,8,2,4,5],[0,4,7]) == ([5,1,3,2,4],[2,8,5])

# %%
supprime_tout_et_renvoie([4,2,3,4,1],[0,1,2,3,4]) == ([],[4,2,3,4,1])

# %%
supprime_tout_et_renvoie(list('ACCTAAGT'),[0,2,4]) == (['C','T','A','G','T'],['A','C','A'])
