# %% [markdown]
# # Evaluation n°2
#
# In this assessment, you will have to deal with the following chapters:
# * While
# * For

# %% [markdown]
# To respond to this assessment:
# * Save your work regularly.
# * Complete the programs or answer the questions in the appropriate cells
# * You WILL NOT MODIFY what is already written in the cells.
# * Some cells will be used to test your functions. You can use it
# * At the end of the assignment, you will save your file.
# * You will return your file via the ENT / work to be done

# %% [markdown]
# For each of the following questions, complete the functions so that they respect the given docstring

# %%
## Question 1
def fonction1(n):
    ''' 
    Function returning the sum of the first n natural numbers.
    You must use a FOR structure
    Exemple if n = 6: sum = 1 + 2 + 3 + 4 + 5 + 6
    : param (int): an integer strictly greater than 0
    : return (int): an integer
    >>> fonction1(6)
    21
    >>> fonction1(9)
    45
    '''
    assert type(n) == int , ' n must be an integer'
    assert n > 0 , 'n must be strictly positive'

    ### A compléter


    return sum

# %%
## Question 2.
### You will also complete the asserts in such a way as to respect the docstring
def fonction2(a,b):
    '''
    Function performing successive subtractions and returning the first value strictly less than 0
    You must use a WHILE structure

    Exemple: a = 2 et b = 9
    9 - 2 = 7 bigger than 0
    7 - 2 = 5 bigger than 0
    5 - 2 = 3 bigger than 0
    3 - 2 = 1 bigger than 0
    1 - 1 = -1 lower than 0
    The returned value is -1    
    : param (int) with a and b strictly positive and a < b
    : return (int)
    >>> fonction2(2,9)
    -1
    >>> fonction2(2,10)
    -2
    '''
    ### To be completed with asserts
    
    ### To be completed with the program
    
    
    return value

# %%
## Question 3.
def fonction3(a):
    '''
    Function that returns the first odd digit in a string of digits
    If the number string only includes even numbers, the returned value is a boolean False
    You are allowed to use multiple "returns"
    : param (str) a word of n digits. Each character is a digit.
    :return (str)
    Example: word='422681654' will return '1' because it is the first odd character
    >>> fonction3('1344')
    '1'
    >>> fonction3('4428261')
    '1'
    >>> fonction3('22222222222')
    False
    '''
    ### A compléter avec les asserts


    ### A compléter avec le programme

# %%
## Question 4.
def fonction4(nombre):
    '''
    Function returning the number of even digits contained in a number passed as a parameter
    : param (int) a strictly positive value
    : return (int)
    Example: number = 467734. There are 3 even numbers: 4, 6 and 4
    The returned value is therefore 3
    >>> fonction4(3346758890)
    5
    >>> fonction4(1234567890)
    5
    '''
    ### To be completed with asserts
    
    ### To be completed with the program

# %%
## Question 5
def fonction5(a,b):
    '''
    Function returning the sum of the natural numbers between a and b
    You will reuse the function1 defined above.
    Example: If a = 3 and b = 6 then the function will calculate the sum:
    sum = 3 + 4 + 5 + 6
    : param (int) a and b two integers such that a < b
    : return (int)
    >>> fonction5(3,6)
    18
    '''
    
    ### To be completed with the program

# %% [markdown]
# To validate a 5-digit entry code (not starting with 0), the following technique is used:
#
# * We calculate the sum of the 4 1st digits
# * If the result is equal to the 5th digit, the code is valid.
# * Otherwise the code is invalid
#
#
# **Example** :
#
#     99999 ---> 9+9+9+9 = 36 ---> 6+3 =9 which is equal to the 5th digit (valid code)
#     10013 ---> 1+0+0+1 = 2 which is not equal to 3 (invalid code)
#
# 1. Write a function `sum_digits(value)` which returns the sum of the digits contained in the character string `value`
#
# 2. Write a `code_is_valide(number)` function which returns True if the code is valid and False otherwise. You will reuse the `sum_digits` function

# %%
def sum_digits(valeur):
    ''' Performs the sum of the digits contained in the character string value
    : param (str) a character string containing numbers
    :return (str)
    >>> sum_digits('123')
    '6'
    >>> sum_digits('9999')
    '36'
    '''
    ## A compléter avec le programme

# %%
def code_is_valid(number):
    ''' Checks the validity of the code
    : param(str): a 5-digit code
    : return (bool)
    >>> code_is_valid('99999')
    True
    >>> code_is_valid('10013')
    False
    '''
    ## A compléter avec le programme

# %%
################################################
###### doctest : test la correction des fonctions
###### Ne pas modifier cette cellule
################################################

if __name__ == "__main__":
	import doctest
	doctest.testmod(verbose = False) # verbose == False si seules erreurs détaillées
