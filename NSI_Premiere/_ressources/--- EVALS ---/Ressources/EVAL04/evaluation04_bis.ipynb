# %% [markdown]
# # Evaluation n°4

# %% [markdown]
# Pour répondre à cette évaluation:
# * Sauvegarder régulièrement votre travail.
# * Compléter les programmes ou répondez aux questions dans les cellules appropriées
# * Vous NE MODIFIEREZ PAS ce qui est déjà écrit dans les cellules.
# * Certaines cellules serviront à tester vos fonctions. Vous pouvez vous en servir
# * A la fin du devoir, vous sauvegarderez votre fichier.
# * Vous rendrez votre fichier via l'ENT / travail à faire

# %% [markdown]
# ## Exercice 1:
#
# Créer une fonction nommée `plus_long(liste)` qui renvoie la chaine de caractère la plus longue de la liste. Vous utiliserez obligatoirement une boucle.

# %%
def plus_long(liste):
    '''
    Renvoie l'élément le plus long de la liste
    : param (list): une liste de str
    : return (str): la chaine de caractère la plus longue de la liste
    >>> plus_long(['a', 'aa' , 'aaaa' , 'a'])
    'aaaa'
    >>> plus_long(['a' , '' , 'aa'])
    ''
    '''
    ### Programme
    
    
    ### Valeur renvoyée

# %% [markdown]
# ## Exercice 2:
#
# Créer une fonction `nbre_positifs(liste)` qui renvoie le nombre de valeurs positives de la liste passée en paramètre

# %%
def nbre_positifs(liste):
    '''
    Renvoie le nombre de valeurs positives de la liste
    : param (list): une liste d'entiers
    : return (int): le nombre de valeurs positives
    >>> nbre_positifs([1,-2,3,-4,5])
    3
    >>> nbre_positifs([])
    0
    >>> nbre_positifs([-4,-5])
    0
    '''
    
    ### Programme
    
    
    ### Valeur renvoyée

# %% [markdown]
# ## Exercice 3:
#
# Créer une fonction `est_pairs(liste)` qui renvoie la liste passée en paramètre en remplaçant les valeurs par `True` si la valeur est paire et `False`si elle est impaire

# %%
def est_pairs(liste):
    '''
    Renvoie une liste contenant `True`si l'élément est pair et `False` sinon
    : param (list): une liste d'entiers
    : return (list): 
    >>> est_pairs([2, 7, 8, 6])
    [True, False, True, True]
    >>> est_pairs([1, 9, 5])
    [False, False, False]
    '''
    ### Programme
    
    
    ### Valeur renvoyée

# %% [markdown]
# ## Exercice 4:
#
# Créer une fonction `somme_colonnes(matrice)` qui renvoie une liste contenant la somme des élements présents dans chaque colonnes de la matrice.
#
# Par exemple:
# $matrice = [[1,2,3],[4,5,6],[7,8,9]]$
#
# devra renvoyer $[12,15,18]$
#
# On supposera que chaque sous liste comporte le même nombre d'élèments

# %%
def somme_colonnes(matrice):
    '''
    Renvoie une liste contenant la somme de chacune des colonne de la matrice
    : param (list): une liste de listes. Chaque élément est un entier
    : return (list): 
    >>> somme_colonnes([[1,2,3],[4,5,6],[7,8,9]])
    [12, 15, 18]
    >>> somme_colonnes([[0,0,0],[0,0,0]])
    [0, 0, 0]
    >>> somme_colonnes([[1,2],[2,3],[4,5]])
    [7, 10]
    '''
    ### Programme
    
    
    ### Valeur renvoyée

# %% [markdown]
# ## Exercice 5:
#
# Créer une fonction `make_liste1(n)` qui renvoie une liste contenant les nombres pairs  inférieurs ou égaux à n. Cette liste devra être générée par itération.

# %%
def make_liste1(n):
    ''' renvoie les nombres pairs  inférieurs ou égaux à n
    : param(n) un entier supérieur strictement à 0
    : return(list)
    >>> make_liste1(6)
    [0, 2, 4, 6]
    >>> make_liste1(3)
    [0, 2]
    '''
    ### Programme
    
    
    ### Valeur renvoyée

# %% [markdown]
# ## Exercice 6:
#
# Créer une fonction `make_liste2(maximum)` qui renvoie une liste contenant les valeurs de 2**n inférieures ou égales à maximum
#
#
# Par exemple si `maximum = 1000` alors la liste renvoyée sera $[1, 2, 4, 8, 16, 32, 64, 128, 256, 512]$

# %%
def make_liste2(maximum):
    ''' renvoie la liste contenant les valeurs de 2**n inférieures ou égales à maximum
    deviennent strictement supérieur à maximum
    : param(maximum) un entier supérieur strictement à 0
    : return(list)
    >>> make_liste2(1)
    [1]
    >>> make_liste2(10)
    [1, 2, 4, 8]
    >>> make_liste2(1000)
    [1, 2, 4, 8, 16, 32, 64, 128, 256, 512]
    >>> make_liste2(16)
    [1, 2, 4, 8, 16]
    '''
    ### Programme
    
    
    ### Valeur renvoyée

# %% [markdown]
# ## Exercice 7: ***Facultatif***
#
# Créer une fonction `longueur_mots(mot)` qui prend en paramètre une phrase (une chaine de caractère) et renvoie une liste contenant la longueur des mots qui la compose.
#
# Par exemple si `mot = 'le petit chat est en train de dormir'`
# alors la liste renvoyée sera $[2, 5, 4, 3, 2, 5, 2, 6]$

# %%
def longueur_mots(mot):
    ''' renvoie la liste contenant la longueur de chaque mot de la liste
    : param(str) une chaine de caractère
    : return(list)
    >>> longueur_mots('le petit chat est en train de dormir')
    [2, 5, 4, 3, 2, 5, 2, 6]
    '''
    ### Programme
    
    
    ### Valeur renvoyée

# %% [markdown]
# ## Exercice 8: ***Facultatif***
#
# Créer une fonction `fabrication_matrice(n)` qui prend en paramètre un entier `n` strictement supérieur à 0.
#
# Cette fonction renverra une matrice "la plus carrée possible"
#
# Imaginez que vous avez n jetons que vous devez ranger en "rangées".
#
# * avec 4 jetons c'est simple. Vous fabriquez un carré de 2 x 2
# * avec 16 jetons, vous fabriquez un carré de 4 x 4
#
# QUe se passe-t-il lorsque vous n'avez pas un carré parfait de jetons. On va donc créer le carré le plus grand possible avec les jetons et on tentera de compléter une ligne supplémentaire avec les jetons restants
#
# * avec 6 jetons, on fabrique un carré de 2 x 2. Il reste 2 jetons que l'on peut insérer pour créer une ligne supplémentaire. On peut donc créer une matrice de 3 lignes et 2 colonnes.
# * avec 24 jetons, on fabrique un carré de 4 x 4. Il reste 8 jetons que l'on peut insérer pour créer deux lignes supplémentaires. On peut donc créer une matrice de 6 lignes et 4 colonnes.
#
# On pourra simuler les jetons en insérant des 'X' dans les cellules de la matrice
#
#
# * Une fois la bibliothèque `math` importée, on pourra utiliser la fonction `sqrt` pour calculer la racine carrée d'un nombre.
#
# a = sqrt(9) donnera à la variable a la valeur 3
#
# * Il est possible de récupérer la partie entière d'un nombre avec la fonction `int`.
#
# a = int(4.5) donnera à la variable a la valeur 4

# %%
from math import *

def fabrication_matrice(n):
    '''
    >>> fabrication_matrice(4)
    [['X', 'X'], ['X', 'X']]
    >>> fabrication_matrice(6)
    [['X', 'X'], ['X', 'X'], ['X', 'X']]
    >>> fabrication_matrice(8)
    [['X', 'X'], ['X', 'X'], ['X', 'X'], ['X', 'X']]
    >>> fabrication_matrice(9)
    [['X', 'X', 'X'], ['X', 'X', 'X'], ['X', 'X', 'X']]
    '''

# %%
################################################
###### doctest : test la correction des fonctions
###### Ne pas modifier cette cellule
################################################

if __name__ == "__main__":
	import doctest
	doctest.testmod(verbose = False) # verbose == False si seules erreurs détaillées
