# %% [markdown]
# # Evaluation n°3

# %% [markdown]
# To respond to this assessment:
# * Save your work regularly.
# * Complete the programs or answer the questions in the appropriate cells
# * You WILL NOT MODIFY what is already written in the cells.
# * Some cells will be used to test your functions. You can use it
# * At the end of the assignment, you will save your file.
# * You will return your file via the ENT / work to be done

# %% [markdown]
# ## Exercice 1:
#
# Create a function `is_list_integer(liste)` which returns `True` if the parameter is a list and contains only integers

# %%
def is_list_integer(liste):
    '''Returns True if the parameter is a list of integers
    >>> is_list_integer([1,2,3])
    True
    >>> is_list_integer([1,'a',3])
    False
    '''

# %% [markdown]
# ## Exercice 2:
#
# Create a function named `smallest(liste)` that returns the smallest element of the list passed as parameter

# %%
def smallest(liste):
    '''
    Returns the smallest item in the list
    : param(list): a list of integers
    : return (int): the smallest integer in the list
    >>> smallest([1,2,3,4,5])
    1
    >>> smallest([1,2,3,4,-6])
    -6
    >>> smallest([1,-1,-5,6])
    -5
    '''
    
    ### Preconditions
    
    
    ### Program
    
    
    ### Return value

# %% [markdown]
# ## Exercice 3:
#
# Create a `num_positives(liste)` function that returns the number of positive values from the list passed as a parameter

# %%
def num_positives(liste):
    '''
    Returns the number of positive or zero values in the list
    : param(list): a list of integers
    : return (int): the number of positive or zero values
    >>> num_positives([1,2,3,4,5])
    5
    >>> num_positives([1,2,3,4,-6])
    4
    >>> num_positives([1,-1,-5,6])
    2
    '''
    
    ### Preconditions
    
    
    ### Program
    
    
    ### Return value

# %% [markdown]
# ## Exercice 4:
#
# Create a function `is_sorted(liste)` which checks if the list passed in parameter is sorted in ascending order. Will return True if so and False otherwise.

# %%
def is_sorted(liste):
    '''
    Returns True if the list is sorted in ascending order and False otherwise
    : param(list): a list of integers
    : return (bool):
    >>> is_sorted([1,2,3,4,5])
    True
    >>> is_sorted([1,2,3,4,-6])
    False
    >>> is_sorted([-6,-1,-1,4,6])
    True
    '''
    
    ### Preconditions
    
    
    ### Program
    
    
    ### Return value

# %% [markdown]
# ## Exercice 5:
#
# Create a `sum_rows(matrix)` function that returns a list containing the sum of the elements present in each row of the matrix.
#
# For instance:
# $matrix = [[1,2,3],[4,5,6],[7,8,9]]$
#
# should return $[6,15,24]$

# %%
def sum_rows(matrix):
    '''
    Returns a list containing the sum of each of the rows of the matrix
    :param(list): a list of lists. Each element is an integer
    : return (list):
    >>> sum_rows([[1,2,3],[4,5,6],[7,8,9]])
    [6,15,24]
    >>> sum_rows([[1,2],[4,5,6],[7,8,9,10]])
    [3,15,34]
    >>> sum_rows([[1,2],[4],[7,8,9],[1,2,3]])
    [3,4,24,6]
    '''
    
    ### Preconditions
    
    
    ### Program
    
    
    ### Return value

# %% [markdown]
# ## Exercice 6:
#
# Create a `list_to_str(liste)` function that converts a list of integers passed as a parameter into a character string.

# %%
def list_to_str(liste):
    ''' Convert the elements of a list into a string
    : param(list) a list of integers
    : return(str)
    >>> list_to_str([1,2,3])
    '123'
    '''
    ### Preconditions
    
    
    ### Program
    
    
    ### Return value

# %%
################################################
###### doctest : test la correction des fonctions
###### Ne pas modifier cette cellule
################################################

if __name__ == "__main__":
	import doctest
	doctest.testmod(verbose = False) # verbose == False si seules erreurs détaillées
