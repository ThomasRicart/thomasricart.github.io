# %% [markdown]
# # Evaluation n°1
#
# In this exam, you will have to deal with the following chapters:
# * variables
# * functions
# * conditions IF

# %% [markdown]
# To respond to this exam:
# * Rename this document : `Name-Surname-eval01` by doing `File \ Rename`
# * Save your work regularly.
# * Complete these codes or answer these questions in the appropriate cells
# * You WILL NOT MODIFY what is already written in the cells.
# * Some cells will be used to test your functions. You can use it
# * At the end of the exam, you will save your file.
# * You will return your file via the ENT / work to be done

# %% [markdown]
# ## Question 1
#
# For each of the following scripts, explain in the cell just below the reason for the error.

# %%
## Question 1.1.
a = 4
b = '5'
c = a + b

# %% [raw]
# *** Explication 1.1. ***

# %%
## Question 1.2.
a = input("enter a value between 0 and 100")
a = a + 4
print(a)

# %% [raw]
# *** Explication 1.2. ***

# %% [markdown]
# ## Question 2
#
# Complete the following functions in order to respect the Docstring

# %%
def fonction1(a):
    '''
    Function returning True if a is strictly positive and False otherwise    : param (int)
    : return (bool)
    >>> fonction1(5)
    True
    >>> fonction1(-5)
    False
    >>> fonction1(0)
    False
    '''
    ### To complete

# %%
### To test your function

# %%
def fonction2(a,b):
    '''
    Function returning the largest value between a and b    
    : param (int)
    : return (int)
    >>> fonction2(2,8)
    8
    >>> fonction2(8,2)
    8
    >>> fonction2(-6,-8)
    -6
    '''
    ### To complete

# %%
### To test your function

# %%
def fonction3(a,b):
    ''' 
    Function returning True if a and b have the same parity (even or odd)
    and False otherwise
    : param (int)
    : return (bool)
    >>> fonction3(6,4)
    True
    >>> fonction3(5,4)
    False
    >>> fonction3(6,3)
    False
    >>> fonction3(3,5)
    True
    '''
    ### To complete

# %%
### To test your function

# %%
################################################
###### doctest : test la correction des fonctions
###### Do not edit this cell
################################################

if __name__ == "__main__":
	import doctest
	doctest.testmod(verbose = False) # verbose == False si seules erreurs détaillées

# %% [markdown]
# ## Question 3
#
# Complete the following assertions in order to respect the Docstring

# %%
def fonction4(a,b):
    ''' 
    : param a and b strictly positive integers with
    a strictly greater than b
        '''
    ### To complete
    ### There can be multiple assert lines
    assert 
    
    ### Part of the program not to be modified
    return a // b

# %%
### To test your function
