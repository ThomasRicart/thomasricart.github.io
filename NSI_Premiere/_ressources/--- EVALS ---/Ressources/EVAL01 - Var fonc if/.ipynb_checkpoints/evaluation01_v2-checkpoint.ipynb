# %% [markdown]
# # Evaluation n°1
#
# Dans cette évaluation, vous aurez à traiter les chapitres suivants:
# * variables
# * fonctions
# * structure IF

# %% [markdown]
# Pour répondre à cette évaluation:
# * Renommer ce document en le nommant: `Nom-Prenom-eval01` en faisant `File \ Rename`
# * Sauvegarder régulièrement votre travail.
# * Compléter les programmes ou répondez aux questions dans les cellules appropriées
# * Vous NE MODIFIEREZ PAS ce qui est déjà écrit dans les cellules.
# * Certaines cellules serviront à tester vos fonctions. Vous pouvez vous en servir
# * A la fin du devoir, vous sauvegarderez votre fichier.
# * Vous rendrez votre fichier via l'ENT / travail à faire

# %% [markdown]
# ## Question 1
#
# Pour chacun des scripts suivants, expliquer dans la fenêtre juste au dessous la raison de l'erreur.

# %%
## Question 1.1.
a = 4
b = '5'
c = a + b

# %% [raw]
# *** Explication 1.1. ***

# %%
## Question 1.2.
a = input("entrer une valeur entre 0 et 100")
a = a + 4
print(a)

# %% [raw]
# *** Explication 1.2. ***

# %% [markdown]
# ## Question 2
#
# Compléter les fonctions suivantes afin de respecter le Docstring

# %%
def fonction1(a,b):
    '''
    Fonction renvoyant True si a est strictement plus grand que b
    et False sinon
    : param (int)
    : return (bool)
    >>> fonction1(2,5)
    False
    >>> fonction1(5,2)
    True
    >>> fonction1(2,2)
    False
    '''
    ### A compléter
    if a > b:
        resultat = True
    else:
        resultat = False
    return resultat

    # version 2
    return (a>b)

# %%
### Pour tester votre fonction
fonction1(2,5)
# Out:
# False

# %%
def fonction2(a):
    '''
    Fonction renvoyant a si a est positif et -a sinon
    : param (int)
    : return (int)
    >>> fonction2(2)
    2
    >>> fonction2(-2)
    2
    '''
    ###  A compléter
    if a >= 0:
        resultat = a
    else: 
        resultat = - a
    return resultat

# %%
### Pour tester votre fonction

# %%
def fonction3(a,b):
    ''' 
    Fonction renvoyant True si a et b ont la meme parité (pair ou impair)
    et False sinon
    : param (int)
    : return (bool)
    >>> fonction3(6,4)
    True
    >>> fonction3(5,4)
    False
    >>> fonction3(6,3)
    False
    >>> fonction3(3,5)
    True
    '''
    ###  A compléter
    if (a%2==0 and b%2==0) or (a%2==1 and b%2==1):
        parite = True
    else:
        parite = False
    return parite

    return (a%2==0 and b%2==0) or (a%2==1 and b%2==1)
    return (a%2 == b%2)

# %%
### Pour tester votre fonction

# %%
################################################
###### doctest : test la correction des fonctions
###### Ne pas modifier cette cellule
################################################

if __name__ == "__main__":
	import doctest
	doctest.testmod(verbose = False) # verbose == False si seules erreurs détaillées

# %% [markdown]
# ## Question 3
#
# Compléter les assertions suivantes afin de respecter le Docstring

# %%
def fonction4(a,b):
    ''' 
    : param a et b des entiers tels que a soit le double de b
    '''
    ### A compléter
    ### Il peut y avoir plusieurs lignes d'assert
    assert type(a) == type(b) == int
    assert a == 2*b
    
    ### Partie du programme à ne pas modifier
    return a // b

# %%
### Pour tester votre fonction
