# %% [markdown]
# <div style="background-color:#1e1e1e;border-radius:12px;overflow:hidden;font-family:'Consolas','Monaco',monospace;box-shadow:0 10px 30px rgba(0,0,0,0.5);border:1px solid #333;">
#     <div style="background-color:#333;padding:12px;display:flex;align-items:center;gap:8px;">
#         <div style="width:12px;height:12px;background:#ff5f56;border-radius:50%;"></div>
#         <div style="width:12px;height:12px;background:#ffbd2e;border-radius:50%;"></div>
#         <div style="width:12px;height:12px;background:#27c93f;border-radius:50%;"></div>
#         <span style="color:#aaa;font-size:13px;margin-left:15px;font-weight:bold;letter-spacing:0.5px;">RD05-ACT1-Repr_textes.ipynb</span>
#     </div>
#     <div style="padding:30px;color:#d4d4d4;line-height:1.6;">
#         <h1 style="color:#4ec9b0;border-bottom:1px solid #444;padding-bottom:10px;margin-top:0;">RD05 : Représentation des textes</h1>
#         <p style="color:#ce9178;margin:15px 0 5px 0;font-size:1.2em;font-weight:bold;"># Thème : Représentation et Traitement des données</p>
#         <p style="color:#9cdcfe;margin:0;font-size:1.1em;font-weight:bold;"># Niveau : 1ère NSI</p>
#         <div style="margin-top:25px;background-color:#252526;padding:15px;border-radius:8px;border-left:4px solid #4ec9b0;">
#
# </div>

# %% [markdown]
# **Exercice 1:**. Le chiffre de César
#
# *Un peu d'histoire*
#
# Le codage César est l'une des plus anciennes méthodes de chiffrement connues. Jules César l'utilisait pour ses correspondances militaires. C’est un chiffrement par décalage : chaque lettre du message est décalée d'un certain rang dans l'alphabet.
#
# *Algorithme et Python*
#
# En informatique, nous utilisons le code ASCII ou Unicode pour représenter les caractères. En Python, la fonction `ord(lettre)` donne le code numérique et `chr(code)` donne le caractère correspondant.

# %% [markdown]
# Compléter la fonction `decale_lettre(lettre, k)` qui décale une lettre majuscule de `k` rangs.

# %%
def decale_lettre(lettre, k):
    ''' Décale une lettre de k positions dans l'alphabet.
        Par exemple, decale_lettre('A', 3) retourne 'D'.
    '''
    # A compléter

assert decale_lettre('A', 3) == 'D'
assert decale_lettre('Z', 1) == 'A'
assert decale_lettre('M', 13) == 'Z'
assert decale_lettre('W', 20) == 'Q'

# %% [markdown]
# Ecrire une fonction `cesar(message, k)` qui décale le message entier de `k` rangs

# %%
def cesar(message, k):
    ''' Applique le chiffrement de César à un message en décalant chaque lettre de k positions.
        Par exemple, cesar("HELLO", 3) retourne "KHOOR".
    '''
    # A compléter


assert cesar("HELLO", 3) == "KHOOR"
assert cesar("WORLD", 5) == "BTWQI"
assert cesar("PYTHON", 10) == "ZIDRYX"

# %% [markdown]
# **Exercice 2:** Le chiffre de Vigenère (Renaissance)
#
# *Le problème de César*
#
# Le chiffre de César est fragile : il n'y a que 26 décalages possibles. Un attaquant peut tester toutes les solutions (force brute) ou utiliser l'analyse de fréquences.
#
# *L'évolution : Le chiffrement polyalphabétique*
#
# Au XVIe siècle, Blaise de Vigenère popularise un système plus robuste. Au lieu d'un décalage fixe, on utilise une clé (un mot). Chaque lettre de la clé représente un décalage:
# | lettre | A | B | C | D |... |
# |---|---|---|---|---|---|
# | décalage| 0 | 1 | 2 | 3 | ... |
#
# * La première lettre du message est décalée selon la 1ère lettre de la clé.
# * La deuxième selon la 2ème lettre de la clé, et ainsi de suite.
#
# Par exemple `'HELLO'` chiffré avec la clé `'KEY'` donne `'RIJVS'`

# %%
def vigenere(message, cle):
    ''' Applique le chiffrement de Vigenère à un message en utilisant une clé.
        Par exemple, vigenere("HELLO", "KEY") retourne "RIJVS".
    '''
    # A compléter

assert vigenere("HELLO", "KEY") == "RIJVS"
assert vigenere("WORLD", "SECRET") == "CJXQE"
assert vigenere("PYTHON", "CODE") == "VQZQZT"
assert vigenere("VIGENERE", "ABC") == "VJHFOFQF"

# %% [markdown]
# **Exercice 3:** Attaque par force brute
#
# Ecrire la fonction `decode_cesar(message_code)` qui prend un message codé de type `str` constitué de majuscules et teste toutes les combinaisons et les affichent au fur et à mesure qu'il les fabrique

# %%
def decode_cesar(message_code):
    ''' Décode un message chiffré avec le chiffrement de César en essayant toutes les possibilités de décalage.
        Par exemple, decode_cesar("KHOOR") retourne une liste de tous les messages possibles en essayant tous les décalages de 1 à 25.  
    '''    # A compléter
