# %% [markdown]
# <div style="background-color:#1e1e1e;border-radius:12px;overflow:hidden;font-family:'Consolas','Monaco',monospace;box-shadow:0 10px 30px rgba(0,0,0,0.5);border:1px solid #333;">
#     <div style="background-color:#333;padding:12px;display:flex;align-items:center;gap:8px;">
#         <div style="width:12px;height:12px;background:#ff5f56;border-radius:50%;"></div>
#         <div style="width:12px;height:12px;background:#ffbd2e;border-radius:50%;"></div>
#         <div style="width:12px;height:12px;background:#27c93f;border-radius:50%;"></div>
#         <span style="color:#aaa;font-size:13px;margin-left:15px;font-weight:bold;letter-spacing:0.5px;">RD03-ACT1-Entiers_relatifs.ipynb</span>
#     </div>
#     <div style="padding:30px;color:#d4d4d4;line-height:1.6;">
#         <h1 style="color:#4ec9b0;border-bottom:1px solid #444;padding-bottom:10px;margin-top:0;">RD03 : Représentation des entiers relatifs</h1>
#         <p style="color:#ce9178;margin:15px 0 5px 0;font-size:1.2em;font-weight:bold;"># Thème : Représentation et Traitement des données</p>
#         <p style="color:#9cdcfe;margin:0;font-size:1.1em;font-weight:bold;"># Niveau : 1ère NSI</p>
#         <div style="margin-top:25px;background-color:#252526;padding:15px;border-radius:8px;border-left:4px solid #4ec9b0;">
#
# </div>

# %% [markdown]
# **Exercice 1:**
#
# Ecrire ou retrouver les codes de vos fonctions
# * `bin2dec(val_bin)` qui transforme une valeur binaire sur 8 bits (type `str`) en entier entre 0 et 255
# * `dec2bin(val_dec)` qui transforme une valeur entière entre 0 et 255 en valeur binaire sur 8 bits (type `str`)

# %%
def bin2dec(val_bin):
    ''' Convertit une chaîne de caractères représentant un nombre binaire sur 8 bits en un entier décimal. '''
    # A compléter



assert bin2dec('00000000') == 0
assert bin2dec('00000001') == 1
assert bin2dec('11011011') == 219
assert bin2dec('01011010') == 90
assert bin2dec('11100011') == 227

# %%
def dec2bin(val_dec):
    ''' Convertit un entier décimal compris entre 0 et 255 en une chaîne de caractères représentant un nombre binaire sur 8 bits. '''
    # A compléter




assert dec2bin(0) == '00000000'
assert dec2bin(1) == '00000001'
assert dec2bin(219) == '11011011'
assert dec2bin(90) == '01011010'
assert dec2bin(227) == '11100011'

# %% [markdown]
# **Exercice 2:** Ecrire une fonction `inverser_bit(bit)` qui prend un `bit` sous forme de chaine de caractère et l'inverse.
#
# * `'0'` devient `'1'`
# * `'1'` devient `'0'`

# %%
def inverser_bit(bit):
    ''' Inverse un bit binaire (0 devient 1 et 1 devient 0). '''
    # A compléter


assert inverser_bit('0') == '1'
assert inverser_bit('1') == '0'

# %% [markdown]
# **Exercice 3:** Ecrire la fonction `ajouter_un(val_bin)` qui renvoie une valeur binaire sur 8 bits à laquelle on a ajouté `'1'`

# %%
def ajouter_un(val_bin):
    ''' Ajoute 1 à un nombre binaire représenté par une chaîne de caractères sur 8 bits. '''
    # A compléter



assert ajouter_un('00000000') == '00000001'
assert ajouter_un('00000001') == '00000010'
assert ajouter_un('00000010') == '00000011'
assert ajouter_un('00000011') == '00000100'
assert ajouter_un('11111110') == '11111111'
assert ajouter_un('11111111') == '00000000'  # Débordement

# %% [markdown]
# **Exercice 4:** Ecrire la fonction `conv_methode1(val_dec)` qui renvoie le codage binaire de `val_dec`.
#
# `val_dec` est un entier compris entre $-128$ et $127$.
#
# Dans cet exercice, vous utiliserez la méthode 1:
#
# 1. Coder la valeur absolue du nombre en binaire
# 2. Inverser les bits de la représentation du nombre en base 2. (complément à 1)
# 3. Additionner 1 au résultat précédent.

# %%
def conv_methode1(val_dec):
    ''' Convertit un entier relatif en binaire en utilisant la méthode 1. '''
    # A compléter

assert conv_methode1(0) == '00000000'
assert conv_methode1(1) == '00000001'
assert conv_methode1(2) == '00000010'
assert conv_methode1(3) == '00000011'
assert conv_methode1(4) == '00000100'
assert conv_methode1(-5) == '11111011'
assert conv_methode1(-1) == '11111111'
assert conv_methode1(-128) == '10000000'
assert conv_methode1(127) == '01111111'

# %% [markdown]
# **Exercice 5:** Ecrire la fonction `conv_methode2(val_dec)` qui renvoie le codage binaire de `val_dec`.
#
# `val_dec` est un entier compris entre $-128$ et $127$.
#
# Dans cet exercice, vous utiliserez la méthode 2:
#
# 1. Coder la valeur absolue du nombre en binaire
# 2. Recopier les valeurs des bits de droite à gauche jusqu’au premier 1 inclus.
# 3. Inverser les bits restant jusqu’au dernier (bit de gauche)

# %%
def conv_methode2(val_dec):
    ''' Convertit un entier relatif en binaire en utilisant la méthode 2. '''
    # A compléter

assert conv_methode2(0) == '00000000'
assert conv_methode2(1) == '00000001'
assert conv_methode2(2) == '00000010'
assert conv_methode2(3) == '00000011'
assert conv_methode2(4) == '00000100'
assert conv_methode2(-5) == '11111011'
assert conv_methode2(-1) == '11111111'
assert conv_methode2(-128) == '10000000'
assert conv_methode2(127) == '01111111'
