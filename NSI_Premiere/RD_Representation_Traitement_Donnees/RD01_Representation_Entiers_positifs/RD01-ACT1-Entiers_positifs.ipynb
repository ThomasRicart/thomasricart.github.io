# %% [markdown]
# <div style="background-color:#1e1e1e;border-radius:12px;overflow:hidden;font-family:'Consolas','Monaco',monospace;box-shadow:0 10px 30px rgba(0,0,0,0.5);border:1px solid #333;">
#     <div style="background-color:#333;padding:12px;display:flex;align-items:center;gap:8px;">
#         <div style="width:12px;height:12px;background:#ff5f56;border-radius:50%;"></div>
#         <div style="width:12px;height:12px;background:#ffbd2e;border-radius:50%;"></div>
#         <div style="width:12px;height:12px;background:#27c93f;border-radius:50%;"></div>
#         <span style="color:#aaa;font-size:13px;margin-left:15px;font-weight:bold;letter-spacing:0.5px;">RD01-ACT1-Entiers_positifs.ipynb</span>
#     </div>
#     <div style="padding:30px;color:#d4d4d4;line-height:1.6;">
#         <h1 style="color:#4ec9b0;border-bottom:1px solid #444;padding-bottom:10px;margin-top:0;">RD01 : Représentation des entiers positifs</h1>
#         <p style="color:#ce9178;margin:15px 0 5px 0;font-size:1.2em;font-weight:bold;"># Thème : Représentation et Traitement des données</p>
#         <p style="color:#9cdcfe;margin:0;font-size:1.1em;font-weight:bold;"># Niveau : 1ère NSI</p>
#         <div style="margin-top:25px;background-color:#252526;padding:15px;border-radius:8px;border-left:4px solid #4ec9b0;">
#
# </div>

# %% [markdown]
# **Exercice 1:**. Vérification des formats d'entrée
#
# Ecrire une fonction `est_octet(val_bin)` qui renvoie `True` si `val_bin` est une chaine de caractère (`str`) composé de 8 bits (`0` ou `1`)

# %%
def est_octet(val_bin):
    ''' Renvoie True si val_bin est un octet, False sinon '''
    # A compléter



assert est_octet('00000000') == True
assert est_octet('11111111') == True
assert est_octet('00011000') == False
assert est_octet('000111000') == False
assert est_octet(34) == False
assert est_octet(True) == False

# %% [markdown]
# Ecrire une fonction `est_int(val_dec)` qui renvoie `True` si `val_dec` est un entier compris entre 0 et 255 inclus et `False` sinon.

# %%
def est_int(val_dec):
    ''' Renvoie True si val_dec est un entier compris entre 0 et 255, False sinon '''
    # A compléter



assert est_int(0) == True
assert est_int(255) == True
assert est_int(34) == True
assert est_int(-1) == False
assert est_int(256) == False
assert est_int('34') == False
assert est_int(True) == False

# %% [markdown]
# **Exercice 2:** Conversion Binaire vers Décimal
#
# Ecrire une fonction `bin2dec(val_bin)` qui prend en entrée une chaine de 8 caractères (ex: `'11011011'`) et renvoie sa valeur entière. Ne fais rien sinon.

# %%
def bin2dec(val_bin):
    ''' Convertit une chaîne de caractères représentant un nombre binaire sur 8 bits en un entier décimal. '''
    # A compléter



assert bin2dec('00000000') == 0
assert bin2dec('00000001') == 1
assert bin2dec('11011011') == 219
assert bin2dec('01011010') == 90
assert bin2dec('11100011') == 227

# %% [markdown]
# **Exercice 3:** Conversion Décimal vers Binaire (Méthode des divisions)
#
# Implémenter la fonction `dec2bin_div(val_dec)` qui prend un entier `val_dec` compris entre 0 et 255 et renvoie la valeur binaire sur 8 bits au type `str`. Ne fait rien sinon

# %%
def dec2bin_div(val_dec):
    ''' Convertit un entier décimal compris entre 0 et 255 en une chaîne de caractères représentant un nombre binaire sur 8 bits, en utilisant la méthode de la division successive. '''
    # A compléter




assert dec2bin_div(0) == '00000000'
assert dec2bin_div(1) == '00000001'
assert dec2bin_div(219) == '11011011'
assert dec2bin_div(90) == '01011010'
assert dec2bin_div(227) == '11100011'

# %% [markdown]
# **Exercice 4:** Conversion Décimal vers Binaire (Méthode des soustraction)
#
# Implémenter la fonction `dec2bin_sous(val_dec)` qui prend un entier `val_dec` compris entre 0 et 255 et renvoie la valeur binaire sur 8 bits au type `str`. Ne fait rien sinon

# %%
def dec2bin_sous(val_dec):
    ''' Convertit un entier décimal compris entre 0 et 255 en une chaîne de caractères représentant un nombre binaire sur 8 bits, en utilisant la méthode de la soustraction successive. '''
    # A compléter




assert dec2bin_sous(0) == '00000000'
assert dec2bin_sous(1) == '00000001'
assert dec2bin_sous(219) == '11011011'
assert dec2bin_sous(90) == '01011010'
assert dec2bin_sous(227) == '11100011'

# %% [markdown]
# **Exercice 5:** Ecrire la fonction `dec2hex(val_dec)` qui convertit un entier décimal compris entre 0 et 255 en une chaîne de caractères représentant un nombre hexadécimal sur 2 chiffres. Par exemple, `dec2hex(219)` doit renvoyer `'DB'`.

# %%
def dec2hex(val_dec):
    ''' Convertit un entier décimal compris entre 0 et 255 en une chaîne de caractères représentant un nombre hexadécimal sur 2 chiffres. '''
    # A compléter

assert dec2hex(0) == '00'
assert dec2hex(1) == '01'
assert dec2hex(219) == 'DB'
assert dec2hex(90) == '5A'

# %% [markdown]
# **Exercice 6:** Ecrire la fonction `hex2dec(val_hex)` qui convertit une valeur hexadécimale sur 2 valeurs en valeur décimale (entre 0 et 255). Par exemple: `hex2dec('DB')` doit renvoyer 219

# %%
def hex2dec(val_hex):
    ''' Convertit une chaîne de caractères représentant un nombre hexadécimal sur 2 chiffres en un entier décimal compris entre 0 et 255. '''
    # A compléter

assert hex2dec('00') == 0
assert hex2dec('01') == 1
assert hex2dec('DB') == 219
assert hex2dec('5A') == 90
