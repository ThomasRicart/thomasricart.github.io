# %% [markdown]
# <div style="background-color:#1e1e1e;border-radius:12px;overflow:hidden;font-family:'Consolas','Monaco',monospace;box-shadow:0 10px 30px rgba(0,0,0,0.5);border:1px solid #333;">
#     <div style="background-color:#333;padding:12px;display:flex;align-items:center;gap:8px;">
#         <div style="width:12px;height:12px;background:#ff5f56;border-radius:50%;"></div>
#         <div style="width:12px;height:12px;background:#ffbd2e;border-radius:50%;"></div>
#         <div style="width:12px;height:12px;background:#27c93f;border-radius:50%;"></div>
#         <span style="color:#aaa;font-size:13px;margin-left:15px;font-weight:bold;letter-spacing:0.5px;">AP07-ACT1-dictionnaires.ipynb</span>
#     </div>
#     <div style="padding:30px;color:#d4d4d4;line-height:1.6;">
#         <h1 style="color:#4ec9b0;margin:0;font-size:2.2em;font-weight:bold;">
#             <span style="color:#569cd6;">&gt;</span> AP07 : Les Dictionnaires</h1>
#         <p style="color:#ce9178;margin:15px 0 5px 0;font-size:1.2em;font-weight:bold;"># Thème : Langage de Programmation</p>
#         <p style="color:#9cdcfe;margin:0;font-size:1.1em;font-weight:bold;"># Niveau : 1ère NSI</p>
#         <div style="margin-top:25px;background-color:#252526;padding:15px;border-radius:8px;border-left:4px solid #4ec9b0;">
#            >>> my_dico = {"NSI": 19, "Maths": 18, "Physique-Chimie": 18}<br>
#            >>> my_dico["NSI"] = 20<br>
#            >>> my_dico["NSI"]<br>
#            20
#
# </div>

# %% [markdown]
# Ce notebook a pour objectif de vous faire découvrir une nouvelle structure de données : les dictionnaires. Mais avant cela, faisons un bref rappel sur les listes.
#
# # 1. Rappels sur les listes
#
# Jusqu'à présent, nous avons utilisé des **tableaux indexés** (les listes en Python) pour stocker des données.
#
# ```python
# ma_liste = ["Alice", 17, "Lyon"]
# ```
#
# **La limite :** Pour retrouver l'âge d'Alice, il faut savoir qu'il est stocké à l'indice 1. Ce n'est pas très pratique pour des données complexes.

# %% [markdown]
# Les listes sont des séquences ordonnées d'éléments. On accède à un élément par son indice (sa position).
#
# |indice `i`|`0`|`1`|`2`|
# |---|---|---|---|
# |élément|`ma_liste[0]`|`ma_liste[1]`|`ma_liste[2]`|
# |valeur|`"Alice"`| `17`| `"Lyon"`|

# %% [markdown]
# !!! question Exercice 1
# On considère la liste suivante:
#
# ```python
# L = [8, 3, 2, 1, 0]
# ```
#
# Complétez les codes suivants afin de respecter les spécifications
# !!!

# %%
L = [8, 3, 2, 1, 0]

### Modifier la liste de manière à passer l'assert
# A compléter

# %%
assert L == [8, 3, 4, 1, 0]

# %%
L = [8, 3, 2, 1, 0]

### Modifie la liste de manière à passer l'assert
# A compléter

# %%
assert L == [8, 3, 2, 1, 0, 4]

# %%
def est_dans_liste(liste, valeur):
    ''' Renvoie True si valeur est dans liste et False sinon '''

# %%
assert est_dans_liste([1, 2, 3], 3)
assert not est_dans_liste([6, 3], 2)
assert not est_dans_liste([], 4)

# %%
def somme_valeurs(liste):
    ''' Renvoie la somme des éléments de la liste '''

# %%
assert somme_valeurs([1, 3, 4]) == 8
assert somme_valeurs([]) == 0
assert somme_valeurs([1, 3, 4, 9]) == 17
assert somme_valeurs([5]) == 5

# %% [markdown]
# # 2. Présentation des dictionnaires
#
# Un **dictionnaire** (`dict` en Python) est une structure de données non ordonnée (en termes d'indexation) qui stocke des couples **Clé : Valeur**.
#
# Contrairement aux listes où l'on utilise des **indices** (0, 1, 2...), on utilise ici des **clés** (souvent des chaînes de caractères) pour retrouver une information.
#
# **Synthaxe:**
#
# * Le dictionnaire vide est `{}`
# * le dictionnaire est de type `dict`
# * chaque paire **clé, valeur** est spéarée par une virgule
# * la **clé** et la **valeur** sont séparées par deux points `:`
#
# ```python
# mon_dico = {}                           # dictionnaire vide
# mon_dico = {'note': 19}                 # clé: 'note', valeur: 16
# mon_dico = {'nom': 'Alice', 'note': 19} # deux couples clé: valeur
# ```
#
# * pour accéder aux valeurs du dictionnaire, il suffit d'appeler la clé
#
# ```python
# >>> mon_dico['note']
# 19
# >>> mon_dico['nom']
# 'Alice'
# ```
#
# * pour créer un couple **clé: valeur** il suffit de taper:
#
# ```python
# mon_dico['age'] = 16
# ```
#
# Le dictionnaire est maintenant modifié
#
# ```python
# >> mon_dico
# {'nom': 'Alice', 'note': 19, 'age': 16}
# ```
#
# **Remarque:**
# Bien que lorsqu'on observe un dictionnaire, on ait l'impression que les couples **clé: valeur** soient ordonnés, en fait ils ne le sont pas. C'est juste un affichage.

# %% [markdown]
# !!! info Exécutez les cellules suivantes et observez ce qu'il se passe
#
#
# !!!

# %%
mon_dico = {}
print(mon_dico)
print(type(mon_dico))
print(len(mon_dico))

### le dictionnaire vide est {}
### le dictionnaire est de type dict
### le dictionnaire contient 0 éléments
# Out:
# {}
# <class 'dict'>
# 0

# %%
mon_dico = {'nom': 'Alice', 'note': 19, 'age': 16}
print(mon_dico)
print(len(mon_dico))

### le dictionnaire n'est plus vide
### le dictionnaire contient 3 éléments
# Out:
# {'nom': 'Alice', 'note': 19, 'age': 16}
# 3

# %%
mon_dico['classe'] = '1NSI'
print(mon_dico)
print(len(mon_dico))

### le dictionnaire contient 4 éléments
### On a ajouté le couple 'classe': '1NSI'
# Out:
# {'nom': 'Alice', 'note': 19, 'age': 16, 'classe': '1NSI'}
# 4

# %%
mon_dico['note'] = 18
print(mon_dico)
print(len(mon_dico))

### le dictionnaire contient toujours 4 éléments
### On a modifié la valeur de la clé 'note'
# Out:
# {'nom': 'Alice', 'note': 18, 'age': 16, 'classe': '1NSI'}
# 4

# %% [markdown]
# !!! question Exercice 2:
# 1. créer un dictionnaire vide nommé `liste_courses`
# 2. ajouter un couple `cle: valeur`: `'banane': 6`
# 3. modifier le nombre de banane et lui donner la valeur `4`
# 4. ajouter un couple `cle: valeur`: `'orange': 2`
# 5. affiche le dictionnaire
# 6. affiche le nombre d'éléments dans le dictionnaire
# 7. affiche le nombre de bananes
# 8. affiche le nombre d'oranges
# 9. affiche le nombre total de fruits
# !!!

# %%
### Code exercice 2
# code 1.

# code 2.

# code 3.

# code 4.

# code 5.

# code 6.

# code 7.

# code 8.

# code 9.

# %% [markdown]
# # 3. Itération sur les dictionnaires
#
# Puisque les dictionnaires ne sont plus ordonnés, on ne peut pas itérer sur les dictionnaires en utilisant les indices.
#
# On va donc  utiliser les méthodes suivantes:
# * `.keys()` pour accéder aux clés
# * `.values()` pour accéder aux valeurs
# * `.items()` pour accéder au couple **cle: valeur**
#
# Les `keys()`, `values()` et `items()` sont des **itérables**.

# %% [markdown]
# !!! question Exercice 2:
#
# Compléter les fonctions suivantes pour respecter le `Docstring`.
#
#
# !!!

# %%
def est_present_cle(dico, cle_cherchee):
    ''' Renvoie True si cle_cherchee est une clé de dico '''

# %%
assert est_present_cle({'Alice': 12, 'Bob': 14, 'Caro': 18}, 'Alice')
assert not est_present_cle({'Alice': 12, 'Bob': 14, 'Caro': 18}, 'David')

# %%
def est_present_val(dico, val_cherchee):
    ''' Renvoie True si val_cherchee est une valeur de dico '''

# %%
assert est_present_val({'Alice': 12, 'Bob': 14, 'Caro': 18}, 14)
assert not est_present_val({'Alice': 12, 'Bob': 14, 'Caro': 18}, 13)

# %%
def est_present(dico, cle_cherchee, val_cherchee):
    ''' Renvoie True si le couple (cle_cherchee, val_cherchee) est dans dico '''

# %%
assert est_present({'Alice': 12, 'Bob': 14, 'Caro': 18}, 'Bob', 14)
assert not est_present({'Alice': 12, 'Bob': 14, 'Caro': 18}, 'Alice', 13)
assert not est_present({'Alice': 12, 'Bob': 14, 'Caro': 18}, 'David', 14)
assert not est_present({'Alice': 12, 'Bob': 14, 'Caro': 18}, 'David', 13)

# %% [markdown]
# !!! question Exercice 3: Vous gérez le panier d'un client.
#
# 1. Calculez le prix total du panier en itérant sur les valeurs.
#
# ```python
# panier = {"Clavier": 45.50, "Souris": 22.00, "Ecran": 189.99, "Tapis": 12.50}
#
# ```
# 2. Appliquez une remise de 10% sur chaque article et stockez les nouveaux prix dans un dictionnaire `panier_promo`.
#
# !!!

# %%
panier = {"Clavier": 45.50, "Souris": 22.00, "Ecran": 189.99, "Tapis": 12.50}

# %%
def calcul_prix_total(panier):
    ''' Renvoie le prix total du panier '''

# %%
assert calcul_prix_total(panier) == 269.99

# %%
def nouveau_panier_remise(panier):
    ''' Renvoie un nouveau panier avec remise de 10% '''

# %%
assert nouveau_panier_remise(panier) == {'Clavier': 40.95, 'Souris': 19.8, 'Ecran': 170.99, 'Tapis': 11.25}

# %% [markdown]
# !!! question Exercice 4: Analyse fréquentielle
#
# On suppose que l'on a une chaine de caractère. L'objectif est de créer un dictionnaire contenant comme clé les différentes lettres présentes dans la chaine de caractère et pour chaque lettre, le nombre de fois où elle apparait comme valeur.
#
# Ne doivent apparaitre que les lettres réellement présentes dans la chaine de caractère.
#
# ```python
# >>> mot = 'abracadabra'
# >>> assert analyse(mot) == {'a': 5, 'b': 2, 'r': 2, 'c': 1, 'd': 1}
# ```
#
# !!!

# %%
mot = 'abracadabra'

def analyse(mot):
    ''' Renvoie un dictionnaire (lettre, nb_fois) '''

# %%
assert analyse(mot) == {'a': 5, 'b': 2, 'r': 2, 'c': 1, 'd': 1}

# %% [markdown]
# !!! question Exercice 6: Le Scrabble
#
# On dispose du dictionnaire suivant, dans lequel chaque lettre de l’aAPhabet (en majuscules) est
# associée au nombre de points qui lui est attribué au scrabble:

# %%
scrabble = {'A': 1, 'B': 3, 'C': 3, 'D': 2, 'E': 1, 'F': 4, 'G': 2, 'H': 4, 'I': 1, 'J': 8, 'K': 10, 'L': 1, 'M': 2,
            'N': 1, 'O': 1, 'P': 3, 'Q': 8, 'R': 1, 'S': 1, 'T': 1, 'U': 1, 'V': 4, 'W': 10, 'X': 10, 'Y': 10, 'Z': 10}

# %% [markdown]
# 1. Compléter définition de la fonction `valeur_mot(mot)` qui prend en paramètre une chaine de caractères constituée de lettres majuscules et qui renvoie le nombre de points que rapporterait ce mot au scrabble.

# %%
def valeur_mot(mot, scrabble):
    ''' Renvoie la valeur du mot selon le dictionnaire scrabble ''' 


assert valeur_mot('PYTHON', scrabble) == 14
assert valeur_mot('NSI', scrabble) == 3

# %% [markdown]
# 2. Compléter la définition de la fonction `meilleure_lettre(mot)` qui prend en paramètre un `mot` de type `str` et renvoie la lettre ayant la plus forte valeur au scrabble.

# %%
def meilleure_lettre(mot, scrabble):
    ''' Renvoie la lettre de mot qui a la plus grande valeur selon scrabble ''' 


assert meilleure_lettre('PYTHON', scrabble) == 'Y'
assert meilleure_lettre('NSI', scrabble) == 'S'

# %% [markdown]
# 3. Au scrabble, il peut y avoir des modificateurs de valeurs:
#
# * chaque valeur de lettre peut être multipliée par 2 ou par 3.
# * le mot entier peut compter double (valeur multipliée par 2) ou triple (valeur multipliée par 3).
#
# On représente cela par la convention suivante:
# * une variable `multiplicateur_lettres` de type `dict`: Par exemple le dictionnaire `{0: 2, 2: 3}` indique que la première lettre est multipliée par 2 et la 3ème lettre multipliée par 3.
# * une variable `multiplicateur_mot` de type `int` qui indique par quelle valeur est multipliée la valeur du mot final. Par exemple si `multiplicateur_mot` vaut 2 alors la valeur finale du mot est multipliée par 2
# * on applique d'abord le multiplicateur des lettres puis celui de mot.
#
# Ecrire la fonction `score_mot(mot, multiplicateur_lettres, multiplicateur_mot)` qui renvoie la valeur finale du mot.

# %%
def score_mot(mot, multiplicateur_lettres, multiplicateur_mot):
    ''' Renvoie le score du mot selon les multiplicateurs '''
    





    
print(score_mot('PYTHON', {1: 2, 4: 3}, 2)) # Affiche 64
print(score_mot('PYTHON', {0: 2, 3: 2}, 3)) # Affiche 84
print(score_mot('NSI', {2: 2}, 3)) # Affiche 12
# Out:
# 64
# 81
# 12

# %% [markdown]
# !!! question Exercice 5: Gestion d'un réseau local
#
# Les différents objets connectés à un réseau sont identifiés par des dictionnaires du type:
# ```python
# {"nom": "PC_Alice", "ip": "192.168.1.50", "role": "Client"}
# ```
#
# Tous ces objets sont stockés dans une liste de dictionnaire de ce type:
#
# ```python
# mon_reseau = [
#     {"nom": "SRV_DHCP", "ip": "192.168.1.1", "role": "Serveur"},
#     {"nom": "PC_Alice", "ip": "192.168.1.50", "role": "Client"},
#     {"nom": "SRV_WEB", "ip": "172.16.0.10", "role": "Serveur"}
# ]
# ```
#
# **Consignes :**
# 1. Créer une fonction `est_present(nom, reseau)` qui renvoie `True` si l'objet dont le nom est `nom` est présent dans le réseau.
# 2. Créer une fonction `get_objet(nom, reseau)` qui renvoie le dictionnaire correspondant au `nom'.
# 3. Créer une fonction `get_ip(nom, reseau)` qui renvoie l'adresse ip de la machine dont le nom est `nom` et `False` sinon.
# 4. Créer une fonction `get_reseau(nom, reseau)` qu renvoie le réseau dans lequel est l'objet. On suppose que tous ces objets ont un masque `255.255.255.0`
# 5. Créer une fonction `est_dans_meme_reseau(nom1, nom2, reseau)` qui renvoie `True` si les deux machines sont dans le même réseau et `False` sinon.
# !!!

# %%
mon_reseau = [
    {"nom": "SRV_DHCP", "ip": "192.168.1.1", "role": "Serveur"},
    {"nom": "PC_Alice", "ip": "192.168.1.50", "role": "Client"},
    {"nom": "SRV_WEB", "ip": "172.16.0.10", "role": "Serveur"}
]

# %%
# question 1
def est_present(nom, reseau):
    ''' Renvoie True si l'objet nom est present dans le réseau '''

# %%
assert est_present('SRV_DHCP', mon_reseau)
assert not est_present('SRV_DNS', mon_reseau)

# %%
# question 2
def get_objet(nom, reseau):
    ''' Renvoie le dictionnaire du nom '''

# %%
assert get_objet('SRV_DHCP', mon_reseau) == {"nom": "SRV_DHCP", "ip": "192.168.1.1", "role": "Serveur"}

# %%
# question 3
def get_ip(nom, reseau):
    ''' Renvoie l'adresse IP de nom '''

# %%
assert get_ip('SRV_DHCP', mon_reseau) == '192.168.1.1'

# %%
# question 4
def get_reseau(nom, reseau):
    ''' Renvoie l'adresse du réseau dans lequel est nom '''

# %%
assert get_reseau('SRV_DHCP', mon_reseau) == '192.168.1.0'

# %%
# question 5
def est_dans_meme_reseau(nom1, nom2, reseau):
    ''' Renvoie True si les deux machines sont dans le même réseau '''

# %%
assert est_dans_meme_reseau('SRV_DHCP', 'PC_Alice', mon_reseau)
assert not est_dans_meme_reseau('SRV_WEB', 'PC_Alice', mon_reseau)
