# %% [markdown]
# <div style="background-color:#1e1e1e;border-radius:12px;overflow:hidden;font-family:'Consolas','Monaco',monospace;box-shadow:0 10px 30px rgba(0,0,0,0.5);border:1px solid #333;">
#     <div style="background-color:#333;padding:12px;display:flex;align-items:center;gap:8px;">
#         <div style="width:12px;height:12px;background:#ff5f56;border-radius:50%;"></div>
#         <div style="width:12px;height:12px;background:#ffbd2e;border-radius:50%;"></div>
#         <div style="width:12px;height:12px;background:#27c93f;border-radius:50%;"></div>
#         <span style="color:#aaa;font-size:13px;margin-left:15px;font-weight:bold;letter-spacing:0.5px;">LP01-constructions_elementaires.ipynb</span>
#     </div>
#     <div style="padding:30px;color:#d4d4d4;line-height:1.6;">
#         <h1 style="color:#4ec9b0;border-bottom:1px solid #444;padding-bottom:10px;margin-top:0;">LP01 : Constructions Élémentaires</h1>
#         <p style="color:#888;font-style:italic;">Ce notebook reprend les bases de la programmation en Python : variables, types de données et opérations sur les chaînes.</p>
#     </div>
# </div>

# %% [markdown]
# ## 1. Variables et Types de données
#
# En Python, on utilise l'opérateur `=` pour l'affectation. Le type est déterminé automatiquement.
#
# **Exercice 1 :** Affectez les valeurs suivantes aux variables et vérifiez leur type avec la fonction `type()`.

# %%
entier = 42
flottant = 3.14
chaine = "NSI"
booleen = True

print(type(entier))
# À vous : affichez le type des autres variables ci-dessous

# %% [markdown]
# ## 2. Opérations Arithmétiques
#
# Python permet de réaliser des calculs complexes. Attention aux opérateurs de division !
#
# **Question :** Calculez le quotient entier (`//`) et le reste (`%`) de la division de 17 par 3.

# %%
a = 17
b = 3

quotient = 
reste = 

print("Quotient :", quotient)
print("Reste :", reste)

# %% [markdown]
# ## 3. Manipulation de chaînes (Slicing)
#
# Le slicing permet d'extraire des parties d'une chaîne avec la syntaxe `[début:fin:pas]`.
#
# **Exercice 2 :** Soit la variable `mot = "Informatique"`.
# 1. Extrayez "Info".
# 2. Extrayez "tique".
# 3. Inversez le mot.

# %%
mot = "Informatique"

print(mot[0:4]) # Doit afficher Info

# À vous :
print() # Affichez tique
print() # Affichez le mot à l'envers

# %% [markdown]
# ## 4. Transtypage (Casting)
#
# La fonction `input()` renvoie toujours une chaîne de caractères (`str`). Il faut la convertir pour faire des calculs.

# %%
annee_naissance = input("Quelle est votre année de naissance ? ")
# Convertissez la saisie en entier pour calculer l'âge
age = 2026 - int(annee_naissance)
print("Vous aurez", age, "ans en 2026.")

# %% [markdown]
# ## 5. Tests de validation (Assert)
#
# Vérifions vos connaissances avec quelques tests.

# %%
def est_pair(n):
    ''' Renvoie True si n est pair '''
    return n % 2 == 0

assert est_pair(10) == True
assert est_pair(7) == False
print("Tests réussis !")
