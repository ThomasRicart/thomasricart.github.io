# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 1: Le minimum à savoir faire en fin de classe de Première</b></u>
# </div>
#
# * <a href="https://www.codepuzzle.io/D7CE5" target="_blank">Sujet 02.1</a> : Ecrire une fonction `max_et_indice`qui prend en paramètre un tableau non vide `tab` de type `list` de nombres entiers et renvoie la valeur du plus grand élément ainsi que l'indice de sa première apparition dans ce tableau
# * <a href="https://www.codepuzzle.io/DH4RX" target="_blank">Sujet 04.1</a> : Conversion binaire vers décimal
#
# * <a href="https://www.codepuzzle.io/D583C" target="_blank">Sujet 05.1</a> : Programmer une fonction `reverse` prenant en paramètre une chaine de caractère non vide `mot` et renvoie cette haine de caractère en ordre inverse
# * <a href="https://www.codepuzzle.io/DLDQA" target="_blank">Sujet 07.1</a> : Créer un dictionnaire contenant les caractères et leurs occurrences dans une chaine de caractère `chaine` donnée en paramètre à la fonction `nbr_occurrences`
# * <a href="https://www.codepuzzle.io/DQM6A" target="_blank">Sujet 10.1</a> : Algorithme de recherche dichotomique dans un tableau `tab` trié par ordre croissant.
# * <a href="https://www.codepuzzle.io/D92AD" target="_blank">Sujet 12.1</a> : Algorithme de fusion de deux listes triées
# * <a href="https://www.codepuzzle.io/D7CE5" target="_blank">Sujet 13.1</a> : Algorithme de recherche dans un tableau.
# * <a href="https://www.codepuzzle.io/D6N9U" target="_blank">Sujet 16.1</a> : Calcul de moyennes pondérées par partir d'une liste de tuples
# * <a href="https://www.codepuzzle.io/DKW5A" target="_blank">Sujet 24.1</a> : Enumération de valeurs d'une liste. Sortie dans un dictionnaire
# * <a href="https://www.codepuzzle.io/DX6YA" target="_blank">Sujet 26.1</a> : Somme de deux dictionnaires
# * <a href="https://www.codepuzzle.io/DKQS6" target="_blank">Sujet 27.1</a> : Vérifie qu'une liste est triée dans l'ordre croissant.
# * <a href="https://www.codepuzzle.io/DTY6H" target="_blank">Sujet 28.1</a> : Détection de doublons dans une liste
# * <a href="https://www.codepuzzle.io/DEYGQ" target="_blank">Sujet 30.1</a> : Compression de valeurs dans une liste. `delta encoding`
# * <a href="https://www.codepuzzle.io/DDPQM" target="_blank">Sujet 34.1</a> : Tri selection
# * <a href="https://www.codepuzzle.io/DXDJ6" target="_blank">Sujet 40.1</a> : Algo de recherche des valeurs supérieures / inferieures et égales à une valeur donnée dans une liste
# * <a href="https://www.codepuzzle.io/D5UDP" target="_blank">Sujet 43.1</a> : Couples consécutifs dans une liste
# * <a href="https://www.codepuzzle.io/D96JH" target="_blank">Sujet 45.1</a> : Mots à trous (str)

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 2</b></u>
# </div>
#
# * <a href="https://www.codepuzzle.io/D8VLB" target="_blank">Sujet 02.2</a> : Détection d'ordre de gènes de chromosomes
# * <a href="https://www.codepuzzle.io/DV5RF" target="_blank">Sujet 05.2</a> : Croible d'Erastosthène
# * <a href="https://www.codepuzzle.io/DW2DX" target="_blank">Sujet 09.2</a> : Recherche dichotomique
# * <a href="https://www.codepuzzle.io/DMZF5" target="_blank">Sujet 14.2</a> : Représentation d'une image par une liste de listes
# * <a href="https://www.codepuzzle.io/DFCNW" target="_blank">Sujet 16.2</a> : Listes de listes / Triangle de Pascal
# * <a href="https://www.codepuzzle.io/DKVBG" target="_blank">Sujet 25.2</a> : Palindrome
# * <a href="https://www.codepuzzle.io/DRAZ7" target="_blank">Sujet 32.2</a> : Algorithme glouton
# * <a href="https://www.codepuzzle.io/D69NE" target="_blank">Sujet 37.2</a> : Tri Insertion
# * <a href="https://www.codepuzzle.io/DS2QL" target="_blank">Sujet 39.2</a> : Tri drapeau
# * <a href="https://www.codepuzzle.io/DH2RX" target="_blank">Sujet 43.2</a> : Codage d'une image
# * <a href="https://www.codepuzzle.io/D3PH8" target="_blank">Sujet 44.2</a> : Représentation d'une image par une liste de listes
