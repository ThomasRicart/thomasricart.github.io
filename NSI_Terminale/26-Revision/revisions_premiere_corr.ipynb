# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 1</b></u>
#
# 1. Créer une variable `a` et lui affecter la valeur `77`
# 2. Afficher le résutat de `a * 8`
# 3. Afficher le quotient de la division euclidienne de `a` par `3`
# 4. Afficher le reste de la division euclidienne de `a` par `3`
# </div>

# %%
# 1. Créer la variable a et lui affectuer 77
a = 77
# 2. Afficher le résultat de a * 8
print(a*8)
# 3. Afficher le quotient de la division euclidienne de a par 3
print(a//3)
# 4. Afficher le reste de la division euclidienne de a par 3
print(a%3)
# Out:
# 616
# 25
# 2

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 2</b></u>
#
# Ecrire une fonction contenant au minimum une instruction `IF` qui correspond à la spécification suivante:
# </div>

# %%
def est_pair(nombre:int)->bool:
    ''' Renvoie True si nombre est pair et False sinon '''
    if nombre % 2 == 0:
        return True
    return False

# %%
# Test de l'exercice 2
# Ne pas modifier le code ci-dessous

assert est_pair(6)
assert not est_pair(7)

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 3</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def est_positif(nombre:int)->bool:
    ''' Renvoie True si nombre est positif et False sinon '''
    if nombre >= 0:
        return True
    return False

# %%
# Test de l'exercice 3
# Ne pas modifier le code ci-dessous

assert est_positif(6)
assert est_positif(0)
assert not est_positif(-7)

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 4</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def elt_positif(liste:list, indice:int)->bool:
    ''' Renvoie True si l'élément de liste à l'indice donné est positif et False sinon 
    On utilisera la fonction est_positif définie précédemment '''
    if liste[indice] >= 0:
        return True
    return False

# %%
assert elt_positif([1, 2, 3], 0)
assert elt_positif([1, 2, 3], 1)    
assert elt_positif([1, 2, 3, -5], 2)
assert not elt_positif([1, -2, -3], 2)

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 5</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def est_liste_positif(liste:list)->bool:
    ''' Renvoie True si tous les éléments de liste sont positifs et False sinon 
    On utilisera la fonction elt_positif définie précédemment '''
    for elt in liste:
        if not est_positif(elt):
            return False
    return True

# %%
assert est_liste_positif([1, 2, 3])
assert est_liste_positif([1, 2, 3, 5])  
assert not est_liste_positif([1, 2, -3])
assert not est_liste_positif([1, -2, 3])

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 6</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def appartient(liste:list, element:int)->bool:
    ''' Renvoie True si element appartient à liste et False sinon '''
    # On utilisera obligatoirement une boucle for ou while pour parcourir la liste
    # On utilisera obligatoirement une structure conditionnelle if pour tester l'appartenance
    for elt in liste:
        if elt == element:
            return True
    return False

# %%
assert appartient([1, 2, 3], 1)
assert appartient([1, 2, 3], 2)     
assert appartient([1, 2, 3, 5], 3)
assert not appartient([1, 2, 3, 5], 4)

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 7</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def compte_occurrences(liste:list, element:int)->int:
    ''' Renvoie le nombre d'occurrences de element dans liste '''
    # On utilisera obligatoirement une boucle for ou while pour parcourir la liste
    # On utilisera obligatoirement une structure conditionnelle if pour tester l'appartenance
    compteur = 0
    for elt in liste:
        if elt == element:
            compteur += 1
    return compteur

# %%
assert compte_occurrences([1, 2, 3], 1) == 1
assert compte_occurrences([1, 2, 3], 2) == 1     
assert compte_occurrences([1, 3, 3, 5], 3) == 2
assert compte_occurrences([1, 2, 3, 5], 4) == 0
assert compte_occurrences([1, 2, 3, 5], 5) == 1
assert compte_occurrences([1, 2, 3, 5], 6) == 0

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 8</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def somme(liste:list)->int:
    ''' Renvoie la somme des éléments de liste '''
    # On utilisera obligatoirement une boucle for ou while pour parcourir la liste
    resultat = 0
    for elt in liste:
        resultat += elt
    return resultat

# %%
assert somme([1, 2, 3]) == 6
assert somme([1, 2, 3, 5]) == 11

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 9</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def make_list(n:int)->list:
    ''' Renvoie une liste contenant les entiers de 0 à n-1 '''
    # On utilisera obligatoirement une boucle for ou while pour construire la liste
    # On utilisera obligatoirement la méthode append pour ajouter un élément à la liste
    liste = []
    for i in range(n):
        liste.append(i)
    return liste

# %%
assert make_list(0) == []
assert make_list(1) == [0]
assert make_list(2) == [0, 1]
assert make_list(3) == [0, 1, 2]

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 10</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def liste_positif(liste:list)->list:
    ''' Renvoie la liste des éléments positifs de liste '''
    # On utilisera obligatoirement une boucle for ou while pour parcourir la liste
    # On utilisera obligatoirement la méthode append pour ajouter un élément à la liste
    liste_positifs = []
    for elt in liste:
        if est_positif(elt):
            liste_positifs.append(elt)
    return liste_positifs

# %%
assert liste_positif([1, 2, 3]) == [1, 2, 3]
assert liste_positif([1, 2, -3]) == [1, 2]    
assert liste_positif([1, -2, 3]) == [1, 3]
assert liste_positif([-1, -2, -3]) == []

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 11</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def liste_vers_chaine(liste:list)->str:
    ''' Renvoie une chaîne de caractères contenant les éléments de liste'''
    # On utilisera obligatoirement une boucle for ou while pour parcourir la liste
    # On utilisera pas la méthode join pour construire la chaîne de caractères
    chaine = ""
    for elt in liste:
        chaine += str(elt)
    return chaine

# %%
assert liste_vers_chaine([1, 2, 3]) == '123'
assert liste_vers_chaine([1, 2, -3]) == '12-3'  
assert liste_vers_chaine([1, -2, 3]) == '1-23'

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 12</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def f(x):
    return x ** 2
def g(x):
    return 2*x+1

def tableau_valeurs(liste:list, fonction)->list:
    ''' Renvoie une liste contenant les tuples (x, f(x)) appliquées à chaque élément de liste '''
    # On utilisera obligatoirement une boucle for ou while pour parcourir la liste
    # On utilisera obligatoirement la méthode append pour ajouter un élément à la liste

    resultat = []
    for elt in liste:
        resultat.append((elt, fonction(elt)))
    return resultat

# %%
assert tableau_valeurs([1, 2, 3], f) == [(1, 1), (2, 4), (3, 9)]
assert tableau_valeurs([1, 2, 3], g) == [(1, 3), (2, 5), (3, 7)]    
assert tableau_valeurs([1, 2, 3, 4], f) == [(1, 1), (2, 4), (3, 9), (4, 16)]

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 13</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def maximum(liste:list)->int:
    ''' Renvoie le maximum de liste '''
    # On utilisera obligatoirement une boucle for ou while pour parcourir la liste
    # On utilisera obligatoirement une structure conditionnelle if pour tester le maximum
    max_val = liste[0]
    for elt in liste:
        if elt > max_val:
            max_val = elt
    return max_val

# %%
assert maximum([1, 2, 3]) == 3
assert maximum([1, 2, -3]) == 2
assert maximum([1, -2, 3]) == 3
assert maximum([-1, -2, -3]) == -1

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 14</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def utilise_dico(dico:dict, cle:str)->str:
    ''' Renvoie la valeur associée à la clé cle dans le dictionnaire dico. Renvoie None si la clé n'existe pas dans le dictionnaire. '''
    if cle in dico:
        return dico[cle]
    return None

# %%
assert utilise_dico({'a': 1, 'b': 2}, 'a') == 1
assert utilise_dico({'a': 1, 'b': 2}, 'b') == 2

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 15</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def compte_lettres(mot:str)->dict:
    ''' Renvoie un dictionnaire contenant le nombre d'occurrences de chaque lettre dans mot '''
    # On utilisera obligatoirement une boucle for ou while pour parcourir les lettres de mot
    # On utilisera obligatoirement une structure conditionnelle if pour tester l'appartenance
    dico = {}
    for lettre in mot:
        if lettre in dico:
            dico[lettre] += 1
        else:
            dico[lettre] = 1
    return dico

# %%
assert compte_lettres('a') == {'a': 1}
assert compte_lettres('aa') == {'a': 2}
assert compte_lettres('ab') == {'a': 1, 'b': 1}
assert compte_lettres('aba') == {'a': 2, 'b': 1}
assert compte_lettres('abc') == {'a': 1, 'b': 1, 'c': 1}
assert compte_lettres('aab') == {'a': 2, 'b': 1}
assert compte_lettres('aabb') == {'a': 2, 'b': 2}   
assert compte_lettres('abracadabra') == {'a': 5, 'b': 2, 'r': 2, 'c': 1, 'd': 1}

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 16</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def dico_to_liste(dico:dict)->list:
    ''' Renvoie une liste contenant les clés du dictionnaire qui ont des valeurs positives ou nulles '''
    # On utilisera obligatoirement une boucle for ou while pour parcourir les clés du dictionnaire
    # On utilisera obligatoirement la méthode append pour ajouter un élément à la liste
    # On utilisera obligatoirement une structure conditionnelle if pour tester la positivité de la clé
    liste = []
    for cle in dico:
        if dico[cle] >= 0:
            liste.append(cle)
    return liste

# %%
assert dico_to_liste({'a': 1, 'b': 2}) == ['a', 'b']
assert dico_to_liste({'a': 1, 'b': -2}) == ['a']  
assert dico_to_liste({'a': -1, 'b': -2}) == []
assert dico_to_liste({'a': 1, 'b': 2, 'c': -3}) == ['a', 'b']
assert dico_to_liste({'a': 1, 'b': 2, 'c': -3, 'd': -4}) == ['a', 'b']

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 17</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def dec_to_binaire(n:int)->str:
    ''' Renvoie la représentation binaire de n sous forme de chaîne de caractères sur 8 bits'''
    # n est un entier compris entre 0 et 255 inclus
    # On utilisera obligatoirement une boucle while pour construire la chaîne de caractères
    # On utilisera pas la fonction bin pour convertir un entier en binaire
    binaire = ""
    while n > 0:
        binaire = str(n % 2) + binaire
        n = n // 2
    while len(binaire) < 8:
        binaire = "0" + binaire
    return binaire

# %%
assert dec_to_binaire(0) == '00000000'
assert dec_to_binaire(1) == '00000001'
assert dec_to_binaire(124) == '01111100'
assert dec_to_binaire(199) == '11000111'
assert dec_to_binaire(255) == '11111111'

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 18</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def bin_to_dec(binaire:str)->int:
    ''' Renvoie la valeur décimale de binaire '''
    # binaire est une chaîne de caractères contenant 8 bits (0 ou 1)
    # On utilisera obligatoirement une boucle for ou while pour parcourir les bits de binaire
    # On utilisera pas la fonction int pour convertir un binaire en décimal
    decimal = 0
    for i in range(len(binaire)):
        decimal += int(binaire[len(binaire) - 1 - i]) * (2 ** i)
    return decimal

# %%
assert bin_to_dec('00000000') == 0
assert bin_to_dec('00110101') == 53
assert bin_to_dec('01111100') == 124
assert bin_to_dec('11000111') == 199
assert bin_to_dec('11111111') == 255

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 19</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante:
# </div>

# %%
def recherche_dicho(liste:list, element:int)->int:
    ''' Renvoie l'indice de element dans liste ou -1 si element n'appartient pas à liste '''
    # On utilisera obligatoirement une boucle while pour parcourir la liste
    # On utilisera obligatoirement une structure conditionnelle if pour tester l'appartenance
    # On supposera que liste est triée par ordre croissant
    # On utilisera la méthode de recherche dichotomique pour trouver l'indice de element dans liste
    debut = 0
    fin = len(liste) - 1
    while debut <= fin:
        milieu = (debut + fin) // 2
        if liste[milieu] == element:
            return milieu
        elif liste[milieu] < element:
            debut = milieu + 1
        else:
            fin = milieu - 1
    return -1

# %%
assert recherche_dicho([1, 2, 3], 1) == 0
assert recherche_dicho([1, 2, 3], 2) == 1
assert recherche_dicho([1, 2, 3], 3) == 2
assert recherche_dicho([1, 2, 3], 4) == -1
assert recherche_dicho([1, 2, 3], 0) == -1
assert recherche_dicho([1, 2, 3, 4], 1) == 0
assert recherche_dicho([1, 2, 3, 4], 2) == 1
assert recherche_dicho([1, 2, 3, 4], 3) == 2

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 20</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante: Le tri par insertion
#
# 1. La liste contenant un seul élément d’indice 0 est triée.
# 2. La clé est le premier élément non trié;
# 3. On compare la clé avec l’élément à sa gauche si on n’a pas atteint le bord gauche;
# 4. Echange des éléments si la clé est inférieure à l’élément de gauche;
# 5. Retour à l’étape 3
# 6. La partie triée gagne un élément;
# 7. Retour à l’étape 2 tant qu’il reste des éléments à trier.
# </div>

# %%
def tri_insertion(liste:list)->list:
    ''' Renvoie la liste triée par ordre croissant '''
    # On utilisera obligatoirement une boucle for ou while pour parcourir la liste
    # On utilisera obligatoirement une structure conditionnelle if pour tester l'appartenance
    # On utilisera pas la méthode sort pour trier la liste
    for i in range(1, len(liste)):
        valeur = liste[i]
        j = i - 1
        while j >= 0 and liste[j] > valeur:
            liste[j + 1] = liste[j]
            j -= 1
        liste[j + 1] = valeur
    return liste

# %%
assert tri_insertion([1, 2, 3]) == [1, 2, 3]
assert tri_insertion([3, 2, 1]) == [1, 2, 3]
assert tri_insertion([2, 1, 3]) == [1, 2, 3]
assert tri_insertion([3, 1, 2]) == [1, 2, 3]
assert tri_insertion([3, 2, 1, 4]) == [1, 2, 3, 4]
assert tri_insertion([4, 3, 2, 1]) == [1, 2, 3, 4]

# %% [markdown]
# <div class="alert " style="border-left: 5px solidrgb(60, 78, 118);border-radius:2px;"> <b><u>Exercice 21</b></u>
#
# Ecrire une fonction qui correspond à la spécification suivante: Le tri par sélection
#
# 1. la liste triée comporte 0 éléments et la liste non triée $n$
# 2. on cherche le minimum de la liste non triée que l’on échange avec le premier élément de la liste non triée;
# 3. la liste triée augmente de 1 élément
# 4. on recommence l’étape 1 jusqu’à ce que la liste triée comporte $n−1$ éléments (le dernier élément est forcément trié).
# </div>

# %%
def recherche_minimum(liste:list)->int:
    ''' Renvoie l'indice du minimum de liste '''
    # On utilisera obligatoirement une boucle for ou while pour parcourir la liste
    # On utilisera obligatoirement une structure conditionnelle if pour tester le minimum
    min_val = liste[0]
    min_index = 0
    for i in range(1, len(liste)):
        if liste[i] < min_val:
            min_val = liste[i]
            min_index = i

    return min_index


assert recherche_minimum([1, 2, 3]) == 0
assert recherche_minimum([3, 2, 1]) == 2
assert recherche_minimum([2, 1, 3]) == 1

# %%
def tri_selection(liste:list)->list:
    ''' Renvoie la liste triée par ordre croissant '''
    # On utilisera obligatoirement une boucle for ou while pour parcourir la liste
    # On utilisera obligatoirement une structure conditionnelle if pour tester l'appartenance
    # On utilisera pas la méthode sort pour trier la liste
    for i in range(len(liste)):
        min_index = recherche_minimum(liste[i:]) + i
        liste[i], liste[min_index] = liste[min_index], liste[i]
    return liste
assert tri_selection([1, 2, 3]) == [1, 2, 3]
assert tri_selection([3, 2, 1]) == [1, 2, 3]
assert tri_selection([3, 1, 2]) == [1, 2, 3]
assert tri_selection([3, 2, 1, 4]) == [1, 2, 3, 4]
